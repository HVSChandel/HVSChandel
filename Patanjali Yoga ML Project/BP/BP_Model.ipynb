# %% [markdown]
# ##Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##Importing the Dataset

# %%
df = pd.read_csv('/content/final_data_BP.csv')
df.drop('ID', axis=1 , inplace=True)

# %%
df.head()
# Out:
#    Gender  Age Alchohol Smoking Non-Veg Exercise         Medication   BMI  \
# 0    Male   37       No      No      No       No                 No  24.1
# 1    Male   47       No      No      No      Yes  Yes(Anxiety/B.P.)  22.8
# 2  Female   47       No      No      No       No       Yes(Thyroid)  28.0
# 3  Female   35       No      No      No       No                 No  27.4
# 4  Female   33       No      No      No       No                 No  22.6
#
#    BP_best
# 0        1
# 1        6
# 2        3
# 3        4
# 4        5

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(sampling_strategy="not majority")
X_res, y_res = ros.fit_resample(X, y)

# %%
y_res
# Out:
# 0     1
# 1     6
# 2     3
# 3     4
# 4     5
#      ..
# 91    6
# 92    6
# 93    6
# 94    6
# 95    6
# Name: BP_best, Length: 96, dtype: int64

# %%
y_res.value_counts()
# Out:
# 1    16
# 6    16
# 3    16
# 4    16
# 5    16
# 2    16
# Name: BP_best, dtype: int64

# %%
X = X_res.values
y = y_res.values

# %%
X
# Out:
# array([['Male', 37, 'No', 'No', 'No', 'No', 'No', 24.1],
#        ['Male', 47, 'No', 'No', 'No', 'Yes', 'Yes(Anxiety/B.P.)', 22.8],
#        ['Female', 47, 'No', 'No', 'No', 'No', 'Yes(Thyroid)', 28.0],
#        ['Female', 35, 'No', 'No', 'No', 'No', 'No', 27.4],
#        ['Female', 33, 'No', 'No', 'No', 'No', 'No', 22.6],
#        ['Female', 45, 'No', 'No', 'No', 'No', 'Yes(B.P.)', 24.5],
#        ['Female', 41, 'No', 'No', 'No', 'No', 'No', 24.5],
#        ['Female', 36, 'No', 'No', 'No', 'No', 'No', 23.2],
#        ['Female', 35, 'No', 'No', 'Yes', 'No', 'Yes(Thyroid)', 25.0],
#        ['Male', 38, 'Yes', 'No', 'Yes', 'No', 'No', 25.8],
#        ['Male', 43, 'Yes', 'Yes', 'Yes', 'No', 'Yes', 30.1],
#        ['Male', 39, 'No', 'No', 'No', 'Yes', 'Yes', 25.4],
#        ['Male', 34, 'Yes', 'No', 'Yes', 'No', 'No', 23.9],
#        ['Female', 34, 'No', 'No', 'No', 'No', 'No', 22.1],
#        ['Female', 29, 'No', 'No', 'Yes', 'No', 'No', 25.7],
#        ['Male', 28, 'No', 'No', 'Yes', 'Yes', 'No', 24.0],
#        ['Male', 28, 'No', 'No', 'Yes', 'No', 'No', 24.3],
#        ['Male', 29, 'No', 'No', 'Yes', 'Yes', 'No', 25.0],
#        ['Male', 30, 'No ', 'No', 'Yes', 'No', 'No', 24.6],
#        ['Male', 34, 'No', 'No', 'Yes', 'Yes', 'No', 28.4],
#        ['Male', 35, 'No', 'No', 'No', 'Yes', 'No', 24.3],
#        ['Male', 39, 'No', 'No', 'Yes', 'No', 'No', 24.3],
#        ['Male', 30, 'No', 'No', 'Yes', 'Yes', 'No', 26.8],
#        ['Male', 45, 'No', 'No', 'Yes', 'No', 'Yes(Sugar)', 21.2],
#        ['Male', 36, 'No', 'No', 'No', 'Yes', 'Yes(CIDP)', 23.8],
#        ['Male', 28, 'No', 'No', 'Yes', 'No', 'No', 22.0],
#        ['Male', 41, 'No', 'No', 'No', 'Yes', 'No', 20.9],
#        ['Male', 34, 'Yes', 'No', 'Yes', 'Yes', 'No', 23.2],
#        ['Male', 37, 'No', 'No', 'Yes', 'Yes', 'No', 22.3],
#        ['Female', 29, 'No', 'No', 'Yes', 'No', 'No', 25.4],
#        ['Female', 39, 'No', 'No', 'Yes', 'No', 'No', 27.5],
#        ['Female', 34, 'No', 'No', 'Yes', 'No', 'No', 18.8],
#        ['Female', 40, 'No', 'No', 'No', 'Yes', 'No', 19.6],
#        ['Female', 29, 'No', 'No', 'Yes', 'No', 'No', 19.0],
#        ['Male', 28, 'Yes', 'No', 'No', 'Yes', 'No', 22.7],
#        ['Male', 28, 'No', 'No', 'Yes', 'No', 'No', 18.9],
#        ['Male', 34, 'Yes', 'No', 'No', 'No', 'No', 22.3],
#        ['Female', 31, 'Yes', 'No', 'No', 'No', 'No', 22.4],
#        ['Male', 39, 'Yes', 'No', 'Yes', 'Yes', 'Yes(Gas)', 22.1],
#        ['Male', 39, 'No', 'No', 'Yes', 'No', 'No', 28.1],
#        ['Female', 37, 'No', 'No', 'Yes', 'No', 'No', 31.4],
#        ['Female', 43, 'No', 'No', 'No', 'Yes', 'No', 26.5],
#        ['Male', 28, 'Yes', 'Yes', 'Yes', 'No', 'No', 18.7],
#        ['Male', 28, 'No', 'No', 'Yes', 'No', 'No', 24.1],
#        ['Male', 31, 'No', 'No', 'No', 'Yes', 'No', 26.9],
#        ['Female', 28, 'No', 'No', 'Yes', 'Yes', 'No', 26.0],
#        ['Female', 30, 'No', 'No', 'No', 'No', 'No', 31.9],
#        ['Male', 36, 'Yes', 'No', 'Yes', 'Yes', 'Yes(B.P.)', 33.1],
#        ['Female', 28, 'No', 'No', 'Yes', 'Yes', 'Yes', 22.6],
#        ['Male', 37, 'No ', 'No', 'No', 'No', 'Yes', 23.8],
#        ['Male', 28, 'No', 'No', 'No', 'Yes', 'No', 27.9],
#        ['Male', 30, 'No', 'No', 'No', 'Yes', 'No', 22.7],
#        ['Male', 29, 'No', 'No', 'No', 'No', 'No', 20.9],
#        ['Male', 31, 'No', 'No', 'Yes', 'Yes', 'No', 19.8],
#        ['Male', 30, 'No', 'No', 'Yes', 'No', 'No', 29.0],
#        ['Male', 31, 'No', 'No', 'No', 'Yes', 'No', 19.5],
#        ['Male', 34, 'No', 'No', 'Yes', 'Yes', 'No', 18.9],
#        ['Male', 28, 'Yes', 'No', 'Yes', 'No', 'No', 27.7],
#        ['Male', 28, 'Yes', 'No', 'Yes', 'No', 'No', 27.7],
#        ['Female', 36, 'No', 'No', 'No', 'No', 'No', 23.2],
#        ['Female', 36, 'No', 'No', 'No', 'No', 'No', 23.2],
#        ['Male', 34, 'No', 'No', 'Yes', 'Yes', 'No', 28.4],
#        ['Male', 39, 'No', 'No', 'Yes', 'No', 'No', 28.1],
#        ['Male', 37, 'No', 'No', 'No', 'No', 'No', 24.1],
#        ['Male', 41, 'No', 'No', 'No', 'Yes', 'No', 20.9],
#        ['Female', 36, 'No', 'No', 'No', 'No', 'No', 23.2],
#        ['Male', 31, 'No', 'No', 'No', 'Yes', 'No', 26.9],
#        ['Male', 34, 'Yes', 'No', 'Yes', 'Yes', 'No', 23.2],
#        ['Female', 41, 'No', 'No', 'No', 'No', 'No', 24.5],
#        ['Male', 31, 'No', 'No', 'No', 'Yes', 'No', 26.9],
#        ['Male', 30, 'No', 'No', 'Yes', 'Yes', 'No', 26.8],
#        ['Female', 28, 'No', 'No', 'Yes', 'Yes', 'Yes', 22.6],
#        ['Male', 28, 'No', 'No', 'Yes', 'No', 'No', 22.0],
#        ['Female', 41, 'No', 'No', 'No', 'No', 'No', 24.5],
#        ['Male', 31, 'No', 'No', 'No', 'Yes', 'No', 26.9],
#        ['Male', 31, 'No', 'No', 'No', 'Yes', 'No', 26.9],
#        ['Female', 47, 'No', 'No', 'No', 'No', 'Yes(Thyroid)', 28.0],
#        ['Male', 36, 'Yes', 'No', 'Yes', 'Yes', 'Yes(B.P.)', 33.1],
#        ['Female', 40, 'No', 'No', 'No', 'Yes', 'No', 19.6],
#        ['Male', 28, 'No', 'No', 'No', 'Yes', 'No', 27.9],
#        ['Male', 28, 'No', 'No', 'Yes', 'No', 'No', 24.3],
#        ['Female', 33, 'No', 'No', 'No', 'No', 'No', 22.6],
#        ['Male', 28, 'No', 'No', 'Yes', 'No', 'No', 24.3],
#        ['Male', 34, 'Yes', 'No', 'Yes', 'No', 'No', 23.9],
#        ['Male', 30, 'No', 'No', 'No', 'Yes', 'No', 22.7],
#        ['Male', 29, 'No', 'No', 'No', 'No', 'No', 20.9],
#        ['Male', 34, 'Yes', 'No', 'Yes', 'No', 'No', 23.9],
#        ['Male', 28, 'No', 'No', 'Yes', 'No', 'No', 24.3],
#        ['Male', 29, 'No', 'No', 'No', 'No', 'No', 20.9],
#        ['Male', 47, 'No', 'No', 'No', 'Yes', 'Yes(Anxiety/B.P.)', 22.8],
#        ['Female', 39, 'No', 'No', 'Yes', 'No', 'No', 27.5],
#        ['Male', 29, 'No', 'No', 'Yes', 'Yes', 'No', 25.0],
#        ['Female', 31, 'Yes', 'No', 'No', 'No', 'No', 22.4],
#        ['Male', 28, 'No', 'No', 'Yes', 'Yes', 'No', 24.0],
#        ['Male', 47, 'No', 'No', 'No', 'Yes', 'Yes(Anxiety/B.P.)', 22.8],
#        ['Male', 39, 'No', 'No', 'No', 'Yes', 'Yes', 25.4]], dtype=object)

# %% [markdown]
# ##LabelEncoding

# %%
for i in range(X.shape[0]):
  for j in range(0, 6):
    if X[i, j] == 'No' or X[i,j] == "Male" or X[i, j] == 'No ':
      X[i, j] = 0
    elif X[i, j] == 'Yes' or X[i,j] == "Female":
      X[i, j] = 1

for i in range(X.shape[0]):
  for j in range(6,7):
    if X[i,j] == 'No':
      X[i,j] = 0
    else:
      X[i,j] = 1
X
# Out:
# array([[0, 37, 0, 0, 0, 0, 0, 24.1],
#        [0, 47, 0, 0, 0, 1, 1, 22.8],
#        [1, 47, 0, 0, 0, 0, 1, 28.0],
#        [1, 35, 0, 0, 0, 0, 0, 27.4],
#        [1, 33, 0, 0, 0, 0, 0, 22.6],
#        [1, 45, 0, 0, 0, 0, 1, 24.5],
#        [1, 41, 0, 0, 0, 0, 0, 24.5],
#        [1, 36, 0, 0, 0, 0, 0, 23.2],
#        [1, 35, 0, 0, 1, 0, 1, 25.0],
#        [0, 38, 1, 0, 1, 0, 0, 25.8],
#        [0, 43, 1, 1, 1, 0, 1, 30.1],
#        [0, 39, 0, 0, 0, 1, 1, 25.4],
#        [0, 34, 1, 0, 1, 0, 0, 23.9],
#        [1, 34, 0, 0, 0, 0, 0, 22.1],
#        [1, 29, 0, 0, 1, 0, 0, 25.7],
#        [0, 28, 0, 0, 1, 1, 0, 24.0],
#        [0, 28, 0, 0, 1, 0, 0, 24.3],
#        [0, 29, 0, 0, 1, 1, 0, 25.0],
#        [0, 30, 0, 0, 1, 0, 0, 24.6],
#        [0, 34, 0, 0, 1, 1, 0, 28.4],
#        [0, 35, 0, 0, 0, 1, 0, 24.3],
#        [0, 39, 0, 0, 1, 0, 0, 24.3],
#        [0, 30, 0, 0, 1, 1, 0, 26.8],
#        [0, 45, 0, 0, 1, 0, 1, 21.2],
#        [0, 36, 0, 0, 0, 1, 1, 23.8],
#        [0, 28, 0, 0, 1, 0, 0, 22.0],
#        [0, 41, 0, 0, 0, 1, 0, 20.9],
#        [0, 34, 1, 0, 1, 1, 0, 23.2],
#        [0, 37, 0, 0, 1, 1, 0, 22.3],
#        [1, 29, 0, 0, 1, 0, 0, 25.4],
#        [1, 39, 0, 0, 1, 0, 0, 27.5],
#        [1, 34, 0, 0, 1, 0, 0, 18.8],
#        [1, 40, 0, 0, 0, 1, 0, 19.6],
#        [1, 29, 0, 0, 1, 0, 0, 19.0],
#        [0, 28, 1, 0, 0, 1, 0, 22.7],
#        [0, 28, 0, 0, 1, 0, 0, 18.9],
#        [0, 34, 1, 0, 0, 0, 0, 22.3],
#        [1, 31, 1, 0, 0, 0, 0, 22.4],
#        [0, 39, 1, 0, 1, 1, 1, 22.1],
#        [0, 39, 0, 0, 1, 0, 0, 28.1],
#        [1, 37, 0, 0, 1, 0, 0, 31.4],
#        [1, 43, 0, 0, 0, 1, 0, 26.5],
#        [0, 28, 1, 1, 1, 0, 0, 18.7],
#        [0, 28, 0, 0, 1, 0, 0, 24.1],
#        [0, 31, 0, 0, 0, 1, 0, 26.9],
#        [1, 28, 0, 0, 1, 1, 0, 26.0],
#        [1, 30, 0, 0, 0, 0, 0, 31.9],
#        [0, 36, 1, 0, 1, 1, 1, 33.1],
#        [1, 28, 0, 0, 1, 1, 1, 22.6],
#        [0, 37, 0, 0, 0, 0, 1, 23.8],
#        [0, 28, 0, 0, 0, 1, 0, 27.9],
#        [0, 30, 0, 0, 0, 1, 0, 22.7],
#        [0, 29, 0, 0, 0, 0, 0, 20.9],
#        [0, 31, 0, 0, 1, 1, 0, 19.8],
#        [0, 30, 0, 0, 1, 0, 0, 29.0],
#        [0, 31, 0, 0, 0, 1, 0, 19.5],
#        [0, 34, 0, 0, 1, 1, 0, 18.9],
#        [0, 28, 1, 0, 1, 0, 0, 27.7],
#        [0, 28, 1, 0, 1, 0, 0, 27.7],
#        [1, 36, 0, 0, 0, 0, 0, 23.2],
#        [1, 36, 0, 0, 0, 0, 0, 23.2],
#        [0, 34, 0, 0, 1, 1, 0, 28.4],
#        [0, 39, 0, 0, 1, 0, 0, 28.1],
#        [0, 37, 0, 0, 0, 0, 0, 24.1],
#        [0, 41, 0, 0, 0, 1, 0, 20.9],
#        [1, 36, 0, 0, 0, 0, 0, 23.2],
#        [0, 31, 0, 0, 0, 1, 0, 26.9],
#        [0, 34, 1, 0, 1, 1, 0, 23.2],
#        [1, 41, 0, 0, 0, 0, 0, 24.5],
#        [0, 31, 0, 0, 0, 1, 0, 26.9],
#        [0, 30, 0, 0, 1, 1, 0, 26.8],
#        [1, 28, 0, 0, 1, 1, 1, 22.6],
#        [0, 28, 0, 0, 1, 0, 0, 22.0],
#        [1, 41, 0, 0, 0, 0, 0, 24.5],
#        [0, 31, 0, 0, 0, 1, 0, 26.9],
#        [0, 31, 0, 0, 0, 1, 0, 26.9],
#        [1, 47, 0, 0, 0, 0, 1, 28.0],
#        [0, 36, 1, 0, 1, 1, 1, 33.1],
#        [1, 40, 0, 0, 0, 1, 0, 19.6],
#        [0, 28, 0, 0, 0, 1, 0, 27.9],
#        [0, 28, 0, 0, 1, 0, 0, 24.3],
#        [1, 33, 0, 0, 0, 0, 0, 22.6],
#        [0, 28, 0, 0, 1, 0, 0, 24.3],
#        [0, 34, 1, 0, 1, 0, 0, 23.9],
#        [0, 30, 0, 0, 0, 1, 0, 22.7],
#        [0, 29, 0, 0, 0, 0, 0, 20.9],
#        [0, 34, 1, 0, 1, 0, 0, 23.9],
#        [0, 28, 0, 0, 1, 0, 0, 24.3],
#        [0, 29, 0, 0, 0, 0, 0, 20.9],
#        [0, 47, 0, 0, 0, 1, 1, 22.8],
#        [1, 39, 0, 0, 1, 0, 0, 27.5],
#        [0, 29, 0, 0, 1, 1, 0, 25.0],
#        [1, 31, 1, 0, 0, 0, 0, 22.4],
#        [0, 28, 0, 0, 1, 1, 0, 24.0],
#        [0, 47, 0, 0, 0, 1, 1, 22.8],
#        [0, 39, 0, 0, 0, 1, 1, 25.4]], dtype=object)

# %% [markdown]
# ##Splitting the Dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (76, 8)

# %% [markdown]
# ##Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.fit_transform(X_test)

# %% [markdown]
# ##Normalisation

# %%
from sklearn.preprocessing import Normalizer
nl_1 = Normalizer()

X_train_normal = nl_1.fit_transform(X_train)
X_test_normal = nl_1.transform(X_test)

# %% [markdown]
# #MODELS

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
# Function to print evaluation metrics
def print_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision_micro = precision_score(y_true, y_pred, average='micro')
    recall_micro = recall_score(y_true, y_pred, average='micro')
    f1_micro = f1_score(y_true, y_pred, average='micro')

    precision_macro = precision_score(y_true, y_pred, average='macro')
    recall_macro = recall_score(y_true, y_pred, average='macro')
    f1_macro = f1_score(y_true, y_pred, average='macro')

    precision_weighted = precision_score(y_true, y_pred, average='weighted')
    recall_weighted = recall_score(y_true, y_pred, average='weighted')
    f1_weighted = f1_score(y_true, y_pred, average='weighted')

    print(f"Accuracy: {accuracy:.10f}")
    print("\nMicro-average:")
    print(f"Precision: {precision_micro:.10f}")
    print(f"Recall: {recall_micro:.10f}")
    print(f"F1 Score: {f1_micro:.10f}")

    print("\nMacro-average:")
    print(f"Precision: {precision_macro:.10f}")
    print(f"Recall: {recall_macro:.10f}")
    print(f"F1 Score: {f1_macro:.10f}")

    print("\nWeighted-average:")
    print(f"Precision: {precision_weighted:.10f}")
    print(f"Recall: {recall_weighted:.10f}")
    print(f"F1 Score: {f1_weighted:.10f}")

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ###Logistic Regression

# %%
lr = LogisticRegression()
lr_params = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'max_iter': [50, 100, 200, 500, 1000],
    'class_weight': [None, 'balanced'],
    'random_state': [42]
}
grid_lr = GridSearchCV(lr, lr_params, cv=5)
grid_lr.fit(X_train_scaled, y_train)
y_pred_lr = grid_lr.predict(X_test_scaled)

# Print details of the Logistic Regression model
print("Logistic Regression:")
print("Best Parameters:", grid_lr.best_params_)
print("Best Score:", grid_lr.best_score_* 100 )
print_metrics(y_test, y_pred_lr)
print("\n")
# Out:
# Logistic Regression:
# Best Parameters: {'C': 0.1, 'class_weight': 'balanced', 'max_iter': 50, 'penalty': 'l2', 'random_state': 42, 'solver': 'newton-cg'}
# Best Score: 30.33333333333333
# Accuracy: 0.3000000000
#
# Micro-average:
# Precision: 0.3000000000
# Recall: 0.3000000000
# F1 Score: 0.3000000000
#
# Macro-average:
# Precision: 0.3194444444
# Recall: 0.3750000000
# F1 Score: 0.2583333333
#
# Weighted-average:
# Precision: 0.3416666667
# Recall: 0.3000000000
# F1 Score: 0.2450000000

# %% [markdown]
# ##KNeighbors

# %%
knn = KNeighborsClassifier()
knn_params = {
    'n_neighbors': [3, 5, 7, 9, 11, 15, 20],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [30, 40, 50, 60],
    'p': [1, 2]
}
grid_knn = GridSearchCV(knn, knn_params, cv=5)
grid_knn.fit(X_train_scaled, y_train)
y_pred_knn = grid_knn.predict(X_test_scaled)

# Print details of the k-Nearest Neighbors model
print("k-Nearest Neighbors:")
print("Best Parameters:", grid_knn.best_params_)
print("Best Score:", grid_knn.best_score_)
print_metrics(y_test, y_pred_knn)
print("\n")
# Out:
# k-Nearest Neighbors:
# Best Parameters: {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 11, 'p': 1, 'weights': 'distance'}
# Best Score: 0.6841666666666667
# Accuracy: 0.3500000000
#
# Micro-average:
# Precision: 0.3500000000
# Recall: 0.3500000000
# F1 Score: 0.3500000000
#
# Macro-average:
# Precision: 0.4027777778
# Recall: 0.3388888889
# F1 Score: 0.3194444444
#
# Weighted-average:
# Precision: 0.4833333333
# Recall: 0.3500000000
# F1 Score: 0.3433333333

# %% [markdown]
# ##SVC

# %%
svm = SVC()
svm_params = {
    'C': [0.1, 1, 10, 100, 1000],
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'gamma': ['scale', 'auto', 0.1, 1, 10, 100],
    'degree': [2, 3, 4],
    'coef0': [0.0, 0.5, 1.0]
}

grid_svm = GridSearchCV(svm, svm_params, cv=5)
grid_svm.fit(X_train_scaled, y_train)
y_pred_svm = grid_svm.predict(X_test_scaled)

# Print details of the Support Vector Machines model
print("Support Vector Machines:")
print("Best Parameters:", grid_svm.best_params_)
print("Best Score:", grid_svm.best_score_)
print_metrics(y_test, y_pred_svm)
print("\n")
# Out:
# Support Vector Machines:
# Best Parameters: {'C': 10, 'coef0': 0.0, 'degree': 2, 'gamma': 10, 'kernel': 'rbf'}
# Best Score: 0.7508333333333334
# Accuracy: 0.1000000000
#
# Micro-average:
# Precision: 0.1000000000
# Recall: 0.1000000000
# F1 Score: 0.1000000000
#
# Macro-average:
# Precision: 0.0166666667
# Recall: 0.1666666667
# F1 Score: 0.0303030303
#
# Weighted-average:
# Precision: 0.0100000000
# Recall: 0.1000000000
# F1 Score: 0.0181818182

# %% [markdown]
# ##Decision Trees

# %%
dt = DecisionTreeClassifier()
dt_params = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 5, 10, 20, 30, 50, 100],
    'min_samples_split': [2, 5, 10, 20, 30, 50],
    'min_samples_leaf': [1, 2, 4, 8, 10, 20]
}

grid_dt = GridSearchCV(dt, dt_params, cv=5)
grid_dt.fit(X_train, y_train)
y_pred_dt = grid_dt.predict(X_test)

# Print details of the Decision Trees model
print("Decision Trees:")
print("Best Parameters:", grid_dt.best_params_)
print("Best Score:", grid_dt.best_score_)
print_metrics(y_test, y_pred_dt)
print("\n")
# Out:
# Decision Trees:
# Best Parameters: {'criterion': 'gini', 'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# Best Score: 0.6983333333333335
# Accuracy: 0.7000000000
#
# Micro-average:
# Precision: 0.7000000000
# Recall: 0.7000000000
# F1 Score: 0.7000000000
#
# Macro-average:
# Precision: 0.6944444444
# Recall: 0.7194444444
# F1 Score: 0.6817460317
#
# Weighted-average:
# Precision: 0.7500000000
# Recall: 0.7000000000
# F1 Score: 0.7030952381

# %% [markdown]
# ##Random Forest

# %%
rf = RandomForestClassifier()
rf_params = {
    'n_estimators': [50, 100, 200, 400, 800],
    'criterion': ['gini'],
    'max_depth': [None, 5, 10, 20,50],
    'min_samples_leaf': [1, 2, 4, 8]
}
grid_rf = GridSearchCV(rf, rf_params, cv=5)
grid_rf.fit(X_train, y_train)
y_pred_rf = grid_rf.predict(X_test)

# Print details of the Random Forest model
print("Random Forest:")
print("Best Parameters:", grid_rf.best_params_)
print("Best Score:", grid_rf.best_score_)
print_metrics(y_test, y_pred_rf)
print("\n")
# Out:
# Random Forest:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 50}
# Best Score: 0.6583333333333333
# Accuracy: 0.7000000000
#
# Micro-average:
# Precision: 0.7000000000
# Recall: 0.7000000000
# F1 Score: 0.7000000000
#
# Macro-average:
# Precision: 0.7833333333
# Recall: 0.7194444444
# F1 Score: 0.6968253968
#
# Weighted-average:
# Precision: 0.8700000000
# Recall: 0.7000000000
# F1 Score: 0.7295238095

# %% [markdown]
# ##Gradient Boosting

# %%
gb = GradientBoostingClassifier()
gb_params = {
    'n_estimators': [50, 100, 200, 400, 800],
    'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.5],
    'max_depth': [3, 5, 7, 9],
    'min_samples_split': [2, 5, 10, 20, 30],
    'min_samples_leaf': [1, 2, 4, 8],
}
grid_gb = GridSearchCV(gb, gb_params, cv=5)
grid_gb.fit(X_train, y_train)
y_pred_gb = grid_gb.predict(X_test)

# Print details of the Gradient Boosting model
print("Gradient Boosting:")
print("Best Parameters:", grid_gb.best_params_)
print("Best Score:", grid_gb.best_score_)
print_metrics(y_test, y_pred_gb)
print("\n")

# %% [markdown]
# ##AdaBoost

# %%
# ada = AdaBoostClassifier()
# ada_params = {
#     'n_estimators': [50, 100, 200, 400, 800],
#     'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.5],
# }
# grid_ada = GridSearchCV(ada, ada_params, cv=5)
# grid_ada.fit(X_train, y_train)
# y_pred_ada = grid_ada.predict(X_test)

# # Print details of the AdaBoost model
# print("AdaBoost:")
# print("Best Parameters:", grid_ada.best_params_)
# print("Best Score:", grid_ada.best_score_)
# print_metrics(y_test, y_pred_ada)
# print("\n")

# %% [markdown]
# ##BaggingClassifier

# %%
bag = BaggingClassifier()
bag_params = {
    'n_estimators': [50, 100, 200, 400, 800],
    'max_samples': [0.1, 0.5, 1.0],
    'max_features': [0.1, 0.5, 1.0],
}
grid_bag = GridSearchCV(bag, bag_params, cv=5)
grid_bag.fit(X_train, y_train)
y_pred_bag = grid_bag.predict(X_test)

# Print details of the Bagging model
print("Bagging:")
print("Best Parameters:", grid_bag.best_params_)
print("Best Score:", grid_bag.best_score_)
print_metrics(y_test, y_pred_bag)
print("\n")

# %% [markdown]
# ##Gaussian Naive Bayes

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred_gnb = gnb.predict(X_test)

# Print details of the Gaussian Naive Bayes model
print("Gaussian Naive Bayes:")
print_metrics(y_test, y_pred_gnb)
print("\n")

# %% [markdown]
# ##LDA

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train)
y_pred_lda = lda.predict(X_test)

# Print details of the Linear Discriminant Analysis model
print("Linear Discriminant Analysis:")
print_metrics(y_test, y_pred_lda)
print("\n")

# %% [markdown]
# ##Quadratic Discriminant Analysis

# %%
qda = QuadraticDiscriminantAnalysis()
qda.fit(X_train, y_train)
y_pred_qda = qda.predict(X_test)

# Print details of the Quadratic Discriminant Analysis model
print("Quadratic Discriminant Analysis:")
print_metrics(y_test, y_pred_qda)
print("\n")

# %% [markdown]
# ##Multi-layer Perceptron

# %%
# mlp = MLPClassifier()
# mlp_params = {
#     'hidden_layer_sizes': [(100,), (50, 50), (100, 50), (100, 100)],
#     'activation': ['relu', 'tanh', 'logistic'],
#     'solver': ['adam', 'sgd'],
#     'learning_rate': ['constant', 'invscaling', 'adaptive'],
#     'max_iter': [100, 200, 400, 800]
# }
# grid_mlp = GridSearchCV(mlp, mlp_params, cv=5)
# grid_mlp.fit(X_train_scaled, y_train)
# y_pred_mlp = grid_mlp.predict(X_test_scaled)

# # Print details of the Multi-layer Perceptron model
# print("Multi-layer Perceptron (Neural Network):")
# print("Best Parameters:", grid_mlp.best_params_)
# print("Best Score:", grid_mlp.best_score_)
# print_metrics(y_test, y_pred_mlp)
# print("\n")

# %% [markdown]
# ##Gaussian Process Classifier

# %%
gpc = GaussianProcessClassifier()
gpc_params = {
    'kernel': [1.0 * RBF(), 2.0 * RBF()],
}
grid_gpc = GridSearchCV(gpc, gpc_params, cv=5)
grid_gpc.fit(X_train_scaled, y_train)
y_pred_gpc = grid_gpc.predict(X_test_scaled)

# Print details of the Gaussian Process Classifier model
print("Gaussian Process Classifier:")
print("Best Parameters:", grid_gpc.best_params_)
print("Best Score:", grid_gpc.best_score_)
print_metrics(y_test, y_pred_gpc)
print("\n")

# %% [markdown]
# ##Dummy Classifier

# %%
dummy = DummyClassifier(strategy="most_frequent")
dummy.fit(X_train, y_train)
y_pred_dummy = dummy.predict(X_test)

# Print details of the Dummy Classifier
print("Dummy Classifier:")
print_metrics(y_test, y_pred_dummy)
print("\n")

# %% [markdown]
# ##Bagging Decision Trees

# %%
bag_dt = BaggingClassifier(base_estimator=DecisionTreeClassifier())
bag_dt_params = {
    'n_estimators': [50, 100, 200, 400, 800],
    'max_samples': [0.1, 0.5, 1.0],
    'max_features': [0.1, 0.5, 1.0],
}
grid_bag_dt = GridSearchCV(bag_dt, bag_dt_params, cv=5)
grid_bag_dt.fit(X_train, y_train)
y_pred_bag_dt = grid_bag_dt.predict(X_test)

# Print details of the Bagging Decision Trees model
print("Bagging Decision Trees:")
print("Best Parameters:", grid_bag_dt.best_params_)
print("Best Score:", grid_bag_dt.best_score_)
print_metrics(y_test, y_pred_bag_dt)
print("\n")

# %% [markdown]
# ##AdaBoost with Decision Trees

# %%
ada_dt = AdaBoostClassifier(base_estimator=DecisionTreeClassifier())
ada_dt_params = {
    'n_estimators': [50, 100, 200, 400, 800],
    'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.5],
}
grid_ada_dt = GridSearchCV(ada_dt, ada_dt_params, cv=5)
grid_ada_dt.fit(X_train, y_train)
y_pred_ada_dt = grid_ada_dt.predict(X_test)

# Print details of the AdaBoost with Decision Trees model
print("AdaBoost with Decision Trees:")
print("Best Parameters:", grid_ada_dt.best_params_)
print("Best Score:", grid_ada_dt.best_score_)
print_metrics(y_test, y_pred_ada_dt)
print("\n")

# %% [markdown]
# ##XGBoost

# %%
import xgboost as xgb
y_train_reduced = y_train - 1
y_test_reduced = y_test - 1

# Rest of your code remains the same
xgb_model = xgb.XGBClassifier()
xgb_params = {
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.5],
    'n_estimators': [50, 100, 200, 400, 800]
}
grid_xgb = GridSearchCV(xgb_model, xgb_params, cv=5)
grid_xgb.fit(X_train, y_train_reduced)
y_pred_xgb = grid_xgb.predict(X_test)

# Print details of the XGBoost model
print("XGBoost:")
print("Best Parameters:", grid_xgb.best_params_)
print("Best Score:", grid_xgb.best_score_)
print_metrics(y_test_reduced, y_pred_xgb)
print("\n")
# Out:
# XGBoost:
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 800}
# Best Score: 0.6041666666666666
# Accuracy: 0.7500000000
#
# Micro-average:
# Precision: 0.7500000000
# Recall: 0.7500000000
# F1 Score: 0.7500000000
#
# Macro-average:
# Precision: 0.8452380952
# Recall: 0.7611111111
# F1 Score: 0.7561327561
#
# Weighted-average:
# Precision: 0.8392857143
# Recall: 0.7500000000
# F1 Score: 0.7406926407

# %% [markdown]
# ##Catboost

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.2)

# %%
from catboost import CatBoostClassifier
cboost = CatBoostClassifier()

parameters = [{'n_estimators': [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]}]
grid_search = GridSearchCV(estimator = cboost,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)
grid_search.fit(X_train, y_train)
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_
print("Best Accuracy: {:.2f} %".format(best_accuracy*100))
print("Best Parameters:", best_parameters)
# Out:
# Learning rate set to 0.038626
# 0:	learn: 1.7771012	total: 3.47ms	remaining: 6.93s
# 1:	learn: 1.7658936	total: 4.91ms	remaining: 4.9s
# 2:	learn: 1.7535616	total: 5.88ms	remaining: 3.92s
# 3:	learn: 1.7383371	total: 8.22ms	remaining: 4.1s
# 4:	learn: 1.7259997	total: 9.14ms	remaining: 3.65s
# 5:	learn: 1.7118232	total: 11.4ms	remaining: 3.78s
# 6:	learn: 1.6981360	total: 12.4ms	remaining: 3.53s
# 7:	learn: 1.6857830	total: 13.6ms	remaining: 3.39s
# 8:	learn: 1.6754603	total: 14.8ms	remaining: 3.28s
# 9:	learn: 1.6641053	total: 16.1ms	remaining: 3.21s
# 10:	learn: 1.6564061	total: 17.1ms	remaining: 3.1s
# 11:	learn: 1.6452368	total: 18.4ms	remaining: 3.06s
# 12:	learn: 1.6335546	total: 19.7ms	remaining: 3.01s
# 13:	learn: 1.6191111	total: 20.9ms	remaining: 2.97s
# 14:	learn: 1.6048853	total: 22.4ms	remaining: 2.96s
# 15:	learn: 1.5949948	total: 23.8ms	remaining: 2.94s
# 16:	learn: 1.5819284	total: 25.1ms	remaining: 2.93s
# 17:	learn: 1.5696042	total: 26.5ms	remaining: 2.92s
# 18:	learn: 1.5579473	total: 27.8ms	remaining: 2.9s
# 19:	learn: 1.5477203	total: 29.1ms	remaining: 2.88s
# 20:	learn: 1.5350832	total: 30.3ms	remaining: 2.86s
# 21:	learn: 1.5268915	total: 31.6ms	remaining: 2.84s
# 22:	learn: 1.5179473	total: 32.4ms	remaining: 2.78s
# 23:	learn: 1.5070687	total: 33.6ms	remaining: 2.77s
# 24:	learn: 1.4959337	total: 34.9ms	remaining: 2.75s
# 25:	learn: 1.4875994	total: 35.7ms	remaining: 2.71s
# 26:	learn: 1.4758787	total: 37ms	remaining: 2.7s
# 27:	learn: 1.4672900	total: 38.4ms	remaining: 2.7s
# 28:	learn: 1.4564997	total: 39.7ms	remaining: 2.69s
# 29:	learn: 1.4445398	total: 41ms	remaining: 2.69s
# 30:	learn: 1.4350834	total: 41.8ms	remaining: 2.66s
# 31:	learn: 1.4254073	total: 43.1ms	remaining: 2.65s
# 32:	learn: 1.4142650	total: 44.4ms	remaining: 2.65s
# 33:	learn: 1.4047828	total: 45.6ms	remaining: 2.64s
# 34:	learn: 1.3946950	total: 46.9ms	remaining: 2.63s
# 35:	learn: 1.3854347	total: 48.2ms	remaining: 2.63s
# 36:	learn: 1.3759660	total: 49.5ms	remaining: 2.63s
# 37:	learn: 1.3659986	total: 50.8ms	remaining: 2.62s
# 38:	learn: 1.3571023	total: 52.1ms	remaining: 2.62s
# 39:	learn: 1.3471463	total: 53.5ms	remaining: 2.62s
# 40:	learn: 1.3398815	total: 54.8ms	remaining: 2.62s
# 41:	learn: 1.3301265	total: 56.1ms	remaining: 2.61s
# 42:	learn: 1.3206422	total: 57.3ms	remaining: 2.61s
# 43:	learn: 1.3124464	total: 58.6ms	remaining: 2.6s
# 44:	learn: 1.3033415	total: 59.9ms	remaining: 2.6s
# 45:	learn: 1.2949675	total: 61.1ms	remaining: 2.6s
# 46:	learn: 1.2856243	total: 62.7ms	remaining: 2.6s
# 47:	learn: 1.2746355	total: 64ms	remaining: 2.6s
# 48:	learn: 1.2696722	total: 64.9ms	remaining: 2.58s
# 49:	learn: 1.2621250	total: 65.9ms	remaining: 2.57s
# 50:	learn: 1.2541030	total: 67.2ms	remaining: 2.57s
# 51:	learn: 1.2476885	total: 68.7ms	remaining: 2.57s
# 52:	learn: 1.2417690	total: 70ms	remaining: 2.57s
# 53:	learn: 1.2351946	total: 71.4ms	remaining: 2.57s
# 54:	learn: 1.2293780	total: 72.6ms	remaining: 2.57s
# 55:	learn: 1.2216910	total: 74ms	remaining: 2.57s
# 56:	learn: 1.2135024	total: 75.4ms	remaining: 2.57s
# 57:	learn: 1.2049421	total: 76.9ms	remaining: 2.57s
# 58:	learn: 1.1969715	total: 78.2ms	remaining: 2.57s
# 59:	learn: 1.1919807	total: 79.4ms	remaining: 2.56s
# 60:	learn: 1.1849238	total: 80.6ms	remaining: 2.56s
# 61:	learn: 1.1796812	total: 81.9ms	remaining: 2.56s
# 62:	learn: 1.1735687	total: 83.2ms	remaining: 2.56s
# 63:	learn: 1.1665424	total: 84.6ms	remaining: 2.56s
# 64:	learn: 1.1583081	total: 85.9ms	remaining: 2.56s
# 65:	learn: 1.1519744	total: 87.3ms	remaining: 2.56s
# 66:	learn: 1.1456603	total: 88.5ms	remaining: 2.55s
# 67:	learn: 1.1379186	total: 89.8ms	remaining: 2.55s
# 68:	learn: 1.1315132	total: 91.3ms	remaining: 2.55s
# 69:	learn: 1.1238273	total: 92.6ms	remaining: 2.55s
# 70:	learn: 1.1160072	total: 93.8ms	remaining: 2.55s
# 71:	learn: 1.1085254	total: 95.1ms	remaining: 2.54s
# 72:	learn: 1.1048672	total: 96.3ms	remaining: 2.54s
# 73:	learn: 1.1012332	total: 97.2ms	remaining: 2.53s
# 74:	learn: 1.0944840	total: 98.4ms	remaining: 2.52s
# 75:	learn: 1.0881374	total: 99.6ms	remaining: 2.52s
# 76:	learn: 1.0801321	total: 101ms	remaining: 2.52s
# 77:	learn: 1.0735571	total: 102ms	remaining: 2.51s
# 78:	learn: 1.0663839	total: 104ms	remaining: 2.53s
# 79:	learn: 1.0646875	total: 104ms	remaining: 2.51s
# 80:	learn: 1.0587994	total: 106ms	remaining: 2.5s
# 81:	learn: 1.0529431	total: 107ms	remaining: 2.51s
# 82:	learn: 1.0463895	total: 108ms	remaining: 2.5s
# 83:	learn: 1.0422285	total: 109ms	remaining: 2.49s
# 84:	learn: 1.0352490	total: 111ms	remaining: 2.5s
# 85:	learn: 1.0302541	total: 112ms	remaining: 2.5s
# 86:	learn: 1.0236198	total: 113ms	remaining: 2.49s
# 87:	learn: 1.0184520	total: 115ms	remaining: 2.49s
# 88:	learn: 1.0123503	total: 116ms	remaining: 2.49s
# 89:	learn: 1.0068888	total: 117ms	remaining: 2.49s
# 90:	learn: 1.0023123	total: 119ms	remaining: 2.49s
# 91:	learn: 0.9964252	total: 120ms	remaining: 2.48s
# 92:	learn: 0.9924071	total: 121ms	remaining: 2.48s
# 93:	learn: 0.9859243	total: 122ms	remaining: 2.48s
# 94:	learn: 0.9823725	total: 123ms	remaining: 2.48s
# 95:	learn: 0.9774388	total: 125ms	remaining: 2.47s
# 96:	learn: 0.9706751	total: 126ms	remaining: 2.47s
# 97:	learn: 0.9661178	total: 127ms	remaining: 2.47s
# 98:	learn: 0.9597851	total: 129ms	remaining: 2.47s
# 99:	learn: 0.9555367	total: 130ms	remaining: 2.46s
# 100:	learn: 0.9500034	total: 131ms	remaining: 2.46s
# 101:	learn: 0.9446632	total: 132ms	remaining: 2.46s
# 102:	learn: 0.9386849	total: 134ms	remaining: 2.46s
# 103:	learn: 0.9336731	total: 135ms	remaining: 2.46s
# 104:	learn: 0.9297149	total: 136ms	remaining: 2.46s
# 105:	learn: 0.9241045	total: 137ms	remaining: 2.45s
# 106:	learn: 0.9190466	total: 139ms	remaining: 2.45s
# 107:	learn: 0.9137292	total: 140ms	remaining: 2.45s
# 108:	learn: 0.9085132	total: 141ms	remaining: 2.45s
# 109:	learn: 0.9044742	total: 142ms	remaining: 2.45s
# 110:	learn: 0.8979941	total: 144ms	remaining: 2.44s
# 111:	learn: 0.8926251	total: 145ms	remaining: 2.44s
# 112:	learn: 0.8891192	total: 146ms	remaining: 2.44s
# 113:	learn: 0.8838933	total: 147ms	remaining: 2.44s
# 114:	learn: 0.8787006	total: 149ms	remaining: 2.44s
# 115:	learn: 0.8733831	total: 150ms	remaining: 2.43s
# 116:	learn: 0.8682995	total: 151ms	remaining: 2.43s
# 117:	learn: 0.8650303	total: 152ms	remaining: 2.43s
# 118:	learn: 0.8601017	total: 154ms	remaining: 2.43s
# 119:	learn: 0.8561085	total: 155ms	remaining: 2.43s
# 120:	learn: 0.8518356	total: 156ms	remaining: 2.42s
# 121:	learn: 0.8468786	total: 157ms	remaining: 2.42s
# 122:	learn: 0.8414888	total: 159ms	remaining: 2.42s
# 123:	learn: 0.8364495	total: 160ms	remaining: 2.42s
# 124:	learn: 0.8309198	total: 161ms	remaining: 2.42s
# 125:	learn: 0.8260144	total: 163ms	remaining: 2.42s
# 126:	learn: 0.8216138	total: 164ms	remaining: 2.42s
# 127:	learn: 0.8201382	total: 165ms	remaining: 2.41s
# 128:	learn: 0.8150897	total: 166ms	remaining: 2.41s
# 129:	learn: 0.8105666	total: 167ms	remaining: 2.41s
# 130:	learn: 0.8062304	total: 169ms	remaining: 2.41s
# 131:	learn: 0.8013655	total: 170ms	remaining: 2.41s
# 132:	learn: 0.7982634	total: 171ms	remaining: 2.41s
# 133:	learn: 0.7946516	total: 173ms	remaining: 2.41s
# 134:	learn: 0.7901892	total: 174ms	remaining: 2.41s
# 135:	learn: 0.7862201	total: 176ms	remaining: 2.41s
# 136:	learn: 0.7826222	total: 177ms	remaining: 2.41s
# 137:	learn: 0.7781425	total: 178ms	remaining: 2.41s
# 138:	learn: 0.7738799	total: 181ms	remaining: 2.42s
# 139:	learn: 0.7696814	total: 183ms	remaining: 2.42s
# 140:	learn: 0.7658022	total: 187ms	remaining: 2.46s
# 141:	learn: 0.7612854	total: 189ms	remaining: 2.48s
# 142:	learn: 0.7571360	total: 192ms	remaining: 2.5s
# 143:	learn: 0.7533054	total: 193ms	remaining: 2.49s
# 144:	learn: 0.7486318	total: 194ms	remaining: 2.48s
# 145:	learn: 0.7438575	total: 195ms	remaining: 2.48s
# 146:	learn: 0.7396731	total: 197ms	remaining: 2.48s
# 147:	learn: 0.7355414	total: 198ms	remaining: 2.48s
# 148:	learn: 0.7313289	total: 199ms	remaining: 2.47s
# 149:	learn: 0.7284690	total: 200ms	remaining: 2.47s
# 150:	learn: 0.7245867	total: 202ms	remaining: 2.47s
# 151:	learn: 0.7221348	total: 203ms	remaining: 2.47s
# 152:	learn: 0.7178771	total: 204ms	remaining: 2.46s
# 153:	learn: 0.7142738	total: 205ms	remaining: 2.46s
# 154:	learn: 0.7105172	total: 207ms	remaining: 2.46s
# 155:	learn: 0.7075775	total: 208ms	remaining: 2.46s
# 156:	learn: 0.7036814	total: 209ms	remaining: 2.46s
# 157:	learn: 0.6992310	total: 211ms	remaining: 2.46s
# 158:	learn: 0.6960793	total: 212ms	remaining: 2.45s
# 159:	learn: 0.6923118	total: 213ms	remaining: 2.45s
# 160:	learn: 0.6893065	total: 215ms	remaining: 2.45s
# 161:	learn: 0.6866719	total: 216ms	remaining: 2.45s
# 162:	learn: 0.6829835	total: 217ms	remaining: 2.44s
# 163:	learn: 0.6795945	total: 218ms	remaining: 2.44s
# 164:	learn: 0.6759546	total: 220ms	remaining: 2.44s
# 165:	learn: 0.6723729	total: 221ms	remaining: 2.44s
# 166:	learn: 0.6684676	total: 222ms	remaining: 2.44s
# 167:	learn: 0.6649358	total: 224ms	remaining: 2.44s
# 168:	learn: 0.6622236	total: 225ms	remaining: 2.44s
# 169:	learn: 0.6607442	total: 226ms	remaining: 2.44s
# 170:	learn: 0.6578264	total: 228ms	remaining: 2.44s
# 171:	learn: 0.6547058	total: 229ms	remaining: 2.44s
# 172:	learn: 0.6509802	total: 231ms	remaining: 2.43s
# 173:	learn: 0.6474726	total: 232ms	remaining: 2.43s
# 174:	learn: 0.6444652	total: 233ms	remaining: 2.43s
# 175:	learn: 0.6414222	total: 234ms	remaining: 2.43s
# 176:	learn: 0.6382786	total: 236ms	remaining: 2.43s
# 177:	learn: 0.6347304	total: 237ms	remaining: 2.42s
# 178:	learn: 0.6326721	total: 238ms	remaining: 2.42s
# 179:	learn: 0.6296101	total: 240ms	remaining: 2.42s
# 180:	learn: 0.6267183	total: 241ms	remaining: 2.42s
# 181:	learn: 0.6244446	total: 242ms	remaining: 2.42s
# 182:	learn: 0.6214488	total: 244ms	remaining: 2.42s
# 183:	learn: 0.6182721	total: 245ms	remaining: 2.42s
# 184:	learn: 0.6163880	total: 246ms	remaining: 2.42s
# 185:	learn: 0.6133968	total: 248ms	remaining: 2.41s
# 186:	learn: 0.6105777	total: 249ms	remaining: 2.41s
# 187:	learn: 0.6077383	total: 250ms	remaining: 2.41s
# 188:	learn: 0.6049810	total: 251ms	remaining: 2.41s
# 189:	learn: 0.6025014	total: 253ms	remaining: 2.41s
# 190:	learn: 0.5994706	total: 254ms	remaining: 2.4s
# 191:	learn: 0.5968482	total: 255ms	remaining: 2.4s
# 192:	learn: 0.5936838	total: 257ms	remaining: 2.4s
# 193:	learn: 0.5910086	total: 258ms	remaining: 2.4s
# 194:	learn: 0.5886367	total: 259ms	remaining: 2.4s
# 195:	learn: 0.5863598	total: 261ms	remaining: 2.4s
# 196:	learn: 0.5837819	total: 262ms	remaining: 2.4s
# 197:	learn: 0.5809128	total: 264ms	remaining: 2.4s
# 198:	learn: 0.5780199	total: 265ms	remaining: 2.4s
# 199:	learn: 0.5749773	total: 266ms	remaining: 2.4s
# 200:	learn: 0.5723882	total: 268ms	remaining: 2.39s
# 201:	learn: 0.5697667	total: 269ms	remaining: 2.39s
# 202:	learn: 0.5674257	total: 270ms	remaining: 2.39s
# 203:	learn: 0.5648450	total: 271ms	remaining: 2.39s
# 204:	learn: 0.5618617	total: 273ms	remaining: 2.39s
# 205:	learn: 0.5592998	total: 274ms	remaining: 2.39s
# 206:	learn: 0.5569440	total: 276ms	remaining: 2.39s
# 207:	learn: 0.5542893	total: 277ms	remaining: 2.39s
# 208:	learn: 0.5519169	total: 279ms	remaining: 2.39s
# 209:	learn: 0.5493996	total: 280ms	remaining: 2.38s
# 210:	learn: 0.5470459	total: 281ms	remaining: 2.38s
# 211:	learn: 0.5452555	total: 282ms	remaining: 2.38s
# 212:	learn: 0.5431583	total: 284ms	remaining: 2.38s
# 213:	learn: 0.5407828	total: 285ms	remaining: 2.38s
# 214:	learn: 0.5381700	total: 286ms	remaining: 2.38s
# 215:	learn: 0.5356533	total: 288ms	remaining: 2.38s
# 216:	learn: 0.5327771	total: 289ms	remaining: 2.37s
# 217:	learn: 0.5317407	total: 290ms	remaining: 2.37s
# 218:	learn: 0.5293012	total: 291ms	remaining: 2.37s
# 219:	learn: 0.5278027	total: 292ms	remaining: 2.37s
# 220:	learn: 0.5257412	total: 294ms	remaining: 2.36s
# 221:	learn: 0.5241342	total: 295ms	remaining: 2.36s
# 222:	learn: 0.5219916	total: 296ms	remaining: 2.36s
# 223:	learn: 0.5197297	total: 298ms	remaining: 2.36s
# 224:	learn: 0.5178315	total: 299ms	remaining: 2.36s
# 225:	learn: 0.5154742	total: 300ms	remaining: 2.36s
# 226:	learn: 0.5134811	total: 302ms	remaining: 2.35s
# 227:	learn: 0.5110968	total: 303ms	remaining: 2.35s
# 228:	learn: 0.5088609	total: 304ms	remaining: 2.35s
# 229:	learn: 0.5073123	total: 306ms	remaining: 2.35s
# 230:	learn: 0.5054930	total: 307ms	remaining: 2.35s
# 231:	learn: 0.5033488	total: 308ms	remaining: 2.35s
# 232:	learn: 0.5010248	total: 309ms	remaining: 2.35s
# 233:	learn: 0.4992835	total: 311ms	remaining: 2.34s
# 234:	learn: 0.4973038	total: 312ms	remaining: 2.34s
# 235:	learn: 0.4956090	total: 313ms	remaining: 2.34s
# 236:	learn: 0.4927775	total: 314ms	remaining: 2.34s
# 237:	learn: 0.4903787	total: 316ms	remaining: 2.34s
# 238:	learn: 0.4882641	total: 317ms	remaining: 2.33s
# 239:	learn: 0.4864649	total: 318ms	remaining: 2.33s
# 240:	learn: 0.4843304	total: 319ms	remaining: 2.33s
# 241:	learn: 0.4823962	total: 321ms	remaining: 2.33s
# 242:	learn: 0.4801947	total: 322ms	remaining: 2.33s
# 243:	learn: 0.4781157	total: 323ms	remaining: 2.33s
# 244:	learn: 0.4760697	total: 324ms	remaining: 2.32s
# 245:	learn: 0.4745994	total: 326ms	remaining: 2.32s
# 246:	learn: 0.4733590	total: 327ms	remaining: 2.32s
# 247:	learn: 0.4711283	total: 328ms	remaining: 2.32s
# 248:	learn: 0.4694383	total: 329ms	remaining: 2.31s
# 249:	learn: 0.4676551	total: 330ms	remaining: 2.31s
# 250:	learn: 0.4660721	total: 332ms	remaining: 2.31s
# 251:	learn: 0.4641372	total: 333ms	remaining: 2.31s
# 252:	learn: 0.4625983	total: 334ms	remaining: 2.31s
# 253:	learn: 0.4607014	total: 335ms	remaining: 2.31s
# 254:	learn: 0.4589814	total: 337ms	remaining: 2.3s
# 255:	learn: 0.4575686	total: 338ms	remaining: 2.3s
# 256:	learn: 0.4561315	total: 339ms	remaining: 2.3s
# 257:	learn: 0.4545556	total: 341ms	remaining: 2.3s
# 258:	learn: 0.4527437	total: 342ms	remaining: 2.3s
# 259:	learn: 0.4508603	total: 343ms	remaining: 2.3s
# 260:	learn: 0.4494132	total: 345ms	remaining: 2.3s
# 261:	learn: 0.4475096	total: 346ms	remaining: 2.3s
# 262:	learn: 0.4456060	total: 348ms	remaining: 2.29s
# 263:	learn: 0.4436849	total: 349ms	remaining: 2.29s
# 264:	learn: 0.4417243	total: 350ms	remaining: 2.29s
# 265:	learn: 0.4403604	total: 352ms	remaining: 2.29s
# 266:	learn: 0.4387704	total: 353ms	remaining: 2.29s
# 267:	learn: 0.4374455	total: 354ms	remaining: 2.29s
# 268:	learn: 0.4359720	total: 355ms	remaining: 2.29s
# 269:	learn: 0.4343762	total: 357ms	remaining: 2.29s
# 270:	learn: 0.4329226	total: 358ms	remaining: 2.28s
# 271:	learn: 0.4312810	total: 359ms	remaining: 2.28s
# 272:	learn: 0.4298016	total: 361ms	remaining: 2.28s
# 273:	learn: 0.4279487	total: 362ms	remaining: 2.28s
# 274:	learn: 0.4265096	total: 363ms	remaining: 2.28s
# 275:	learn: 0.4246756	total: 365ms	remaining: 2.28s
# 276:	learn: 0.4232282	total: 366ms	remaining: 2.28s
# 277:	learn: 0.4214200	total: 367ms	remaining: 2.27s
# 278:	learn: 0.4199752	total: 370ms	remaining: 2.28s
# 279:	learn: 0.4185999	total: 377ms	remaining: 2.31s
# 280:	learn: 0.4169844	total: 380ms	remaining: 2.32s
# 281:	learn: 0.4152935	total: 382ms	remaining: 2.33s
# 282:	learn: 0.4139109	total: 383ms	remaining: 2.32s
# 283:	learn: 0.4124977	total: 384ms	remaining: 2.32s
# 284:	learn: 0.4107873	total: 386ms	remaining: 2.32s
# 285:	learn: 0.4096357	total: 387ms	remaining: 2.32s
# 286:	learn: 0.4087257	total: 388ms	remaining: 2.32s
# 287:	learn: 0.4073635	total: 390ms	remaining: 2.32s
# 288:	learn: 0.4058112	total: 391ms	remaining: 2.31s
# 289:	learn: 0.4044703	total: 392ms	remaining: 2.31s
# 290:	learn: 0.4029041	total: 394ms	remaining: 2.31s
# 291:	learn: 0.4014627	total: 395ms	remaining: 2.31s
# 292:	learn: 0.3999164	total: 396ms	remaining: 2.31s
# 293:	learn: 0.3984328	total: 398ms	remaining: 2.31s
# 294:	learn: 0.3970515	total: 399ms	remaining: 2.31s
# 295:	learn: 0.3954425	total: 401ms	remaining: 2.31s
# 296:	learn: 0.3938096	total: 402ms	remaining: 2.3s
# 297:	learn: 0.3927714	total: 403ms	remaining: 2.3s
# 298:	learn: 0.3914885	total: 404ms	remaining: 2.3s
# 299:	learn: 0.3902777	total: 406ms	remaining: 2.3s
# 300:	learn: 0.3888418	total: 407ms	remaining: 2.3s
# 301:	learn: 0.3879667	total: 408ms	remaining: 2.29s
# 302:	learn: 0.3866539	total: 410ms	remaining: 2.29s
# 303:	learn: 0.3858903	total: 411ms	remaining: 2.29s
# 304:	learn: 0.3850465	total: 412ms	remaining: 2.29s
# 305:	learn: 0.3837475	total: 413ms	remaining: 2.29s
# 306:	learn: 0.3819847	total: 415ms	remaining: 2.29s
# 307:	learn: 0.3806896	total: 416ms	remaining: 2.29s
# 308:	learn: 0.3796596	total: 417ms	remaining: 2.28s
# 309:	learn: 0.3784119	total: 419ms	remaining: 2.28s
# 310:	learn: 0.3768218	total: 420ms	remaining: 2.28s
# 311:	learn: 0.3753261	total: 421ms	remaining: 2.28s
# 312:	learn: 0.3739899	total: 423ms	remaining: 2.28s
# 313:	learn: 0.3722435	total: 424ms	remaining: 2.28s
# 314:	learn: 0.3707756	total: 425ms	remaining: 2.27s
# 315:	learn: 0.3696990	total: 426ms	remaining: 2.27s
# 316:	learn: 0.3683371	total: 428ms	remaining: 2.27s
# 317:	learn: 0.3669135	total: 429ms	remaining: 2.27s
# 318:	learn: 0.3653449	total: 430ms	remaining: 2.27s
# 319:	learn: 0.3642765	total: 432ms	remaining: 2.27s
# 320:	learn: 0.3628137	total: 433ms	remaining: 2.26s
# 321:	learn: 0.3617126	total: 434ms	remaining: 2.26s
# 322:	learn: 0.3604951	total: 435ms	remaining: 2.26s
# 323:	learn: 0.3594199	total: 437ms	remaining: 2.26s
# 324:	learn: 0.3585340	total: 438ms	remaining: 2.26s
# 325:	learn: 0.3572143	total: 439ms	remaining: 2.25s
# 326:	learn: 0.3558126	total: 440ms	remaining: 2.25s
# 327:	learn: 0.3545768	total: 442ms	remaining: 2.25s
# 328:	learn: 0.3534256	total: 443ms	remaining: 2.25s
# 329:	learn: 0.3522003	total: 444ms	remaining: 2.25s
# 330:	learn: 0.3510412	total: 446ms	remaining: 2.25s
# 331:	learn: 0.3500902	total: 447ms	remaining: 2.25s
# 332:	learn: 0.3490055	total: 448ms	remaining: 2.24s
# 333:	learn: 0.3476953	total: 450ms	remaining: 2.24s
# 334:	learn: 0.3463941	total: 451ms	remaining: 2.24s
# 335:	learn: 0.3454129	total: 452ms	remaining: 2.24s
# 336:	learn: 0.3443430	total: 454ms	remaining: 2.24s
# 337:	learn: 0.3435050	total: 455ms	remaining: 2.24s
# 338:	learn: 0.3422640	total: 456ms	remaining: 2.23s
# 339:	learn: 0.3414932	total: 457ms	remaining: 2.23s
# 340:	learn: 0.3404921	total: 459ms	remaining: 2.23s
# 341:	learn: 0.3394427	total: 460ms	remaining: 2.23s
# 342:	learn: 0.3383049	total: 461ms	remaining: 2.23s
# 343:	learn: 0.3371080	total: 463ms	remaining: 2.23s
# 344:	learn: 0.3359646	total: 464ms	remaining: 2.23s
# 345:	learn: 0.3347409	total: 465ms	remaining: 2.22s
# 346:	learn: 0.3338702	total: 466ms	remaining: 2.22s
# 347:	learn: 0.3327931	total: 468ms	remaining: 2.22s
# 348:	learn: 0.3316744	total: 469ms	remaining: 2.22s
# 349:	learn: 0.3304058	total: 470ms	remaining: 2.21s
# 350:	learn: 0.3293688	total: 471ms	remaining: 2.21s
# 351:	learn: 0.3283326	total: 473ms	remaining: 2.21s
# 352:	learn: 0.3271304	total: 474ms	remaining: 2.21s
# 353:	learn: 0.3263583	total: 475ms	remaining: 2.21s
# 354:	learn: 0.3251907	total: 476ms	remaining: 2.21s
# 355:	learn: 0.3242101	total: 477ms	remaining: 2.2s
# 356:	learn: 0.3233885	total: 478ms	remaining: 2.2s
# 357:	learn: 0.3226541	total: 480ms	remaining: 2.2s
# 358:	learn: 0.3218023	total: 481ms	remaining: 2.2s
# 359:	learn: 0.3203869	total: 482ms	remaining: 2.19s
# 360:	learn: 0.3193079	total: 483ms	remaining: 2.19s
# 361:	learn: 0.3182705	total: 484ms	remaining: 2.19s
# 362:	learn: 0.3171531	total: 486ms	remaining: 2.19s
# 363:	learn: 0.3162162	total: 487ms	remaining: 2.19s
# 364:	learn: 0.3152230	total: 488ms	remaining: 2.19s
# 365:	learn: 0.3143097	total: 492ms	remaining: 2.2s
# 366:	learn: 0.3135648	total: 493ms	remaining: 2.19s
# 367:	learn: 0.3123169	total: 495ms	remaining: 2.19s
# 368:	learn: 0.3114400	total: 497ms	remaining: 2.2s
# 369:	learn: 0.3105993	total: 499ms	remaining: 2.2s
# 370:	learn: 0.3096160	total: 502ms	remaining: 2.2s
# 371:	learn: 0.3086658	total: 504ms	remaining: 2.21s
# 372:	learn: 0.3080523	total: 507ms	remaining: 2.21s
# 373:	learn: 0.3071336	total: 508ms	remaining: 2.21s
# 374:	learn: 0.3063686	total: 509ms	remaining: 2.21s
# 375:	learn: 0.3054272	total: 511ms	remaining: 2.21s
# 376:	learn: 0.3044119	total: 512ms	remaining: 2.2s
# 377:	learn: 0.3032074	total: 513ms	remaining: 2.2s
# 378:	learn: 0.3023489	total: 515ms	remaining: 2.2s
# 379:	learn: 0.3014475	total: 516ms	remaining: 2.2s
# 380:	learn: 0.3006140	total: 517ms	remaining: 2.2s
# 381:	learn: 0.3001881	total: 518ms	remaining: 2.19s
# 382:	learn: 0.2993930	total: 519ms	remaining: 2.19s
# 383:	learn: 0.2987651	total: 521ms	remaining: 2.19s
# 384:	learn: 0.2979891	total: 522ms	remaining: 2.19s
# 385:	learn: 0.2972347	total: 523ms	remaining: 2.19s
# 386:	learn: 0.2965772	total: 524ms	remaining: 2.19s
# 387:	learn: 0.2956581	total: 526ms	remaining: 2.18s
# 388:	learn: 0.2949063	total: 527ms	remaining: 2.18s
# 389:	learn: 0.2942333	total: 528ms	remaining: 2.18s
# 390:	learn: 0.2937868	total: 529ms	remaining: 2.18s
# 391:	learn: 0.2931569	total: 531ms	remaining: 2.18s
# 392:	learn: 0.2924035	total: 532ms	remaining: 2.17s
# 393:	learn: 0.2915806	total: 533ms	remaining: 2.17s
# 394:	learn: 0.2906709	total: 535ms	remaining: 2.17s
# 395:	learn: 0.2899955	total: 536ms	remaining: 2.17s
# 396:	learn: 0.2891573	total: 537ms	remaining: 2.17s
# 397:	learn: 0.2883514	total: 539ms	remaining: 2.17s
# 398:	learn: 0.2875305	total: 540ms	remaining: 2.17s
# 399:	learn: 0.2866562	total: 541ms	remaining: 2.17s
# 400:	learn: 0.2856901	total: 543ms	remaining: 2.16s
# 401:	learn: 0.2846357	total: 544ms	remaining: 2.16s
# 402:	learn: 0.2838595	total: 545ms	remaining: 2.16s
# 403:	learn: 0.2829152	total: 547ms	remaining: 2.16s
# 404:	learn: 0.2819318	total: 548ms	remaining: 2.16s
# 405:	learn: 0.2811908	total: 549ms	remaining: 2.16s
# 406:	learn: 0.2802967	total: 550ms	remaining: 2.15s
# 407:	learn: 0.2796896	total: 552ms	remaining: 2.15s
# 408:	learn: 0.2789262	total: 553ms	remaining: 2.15s
# 409:	learn: 0.2780432	total: 554ms	remaining: 2.15s
# 410:	learn: 0.2771145	total: 555ms	remaining: 2.15s
# 411:	learn: 0.2761324	total: 557ms	remaining: 2.15s
# 412:	learn: 0.2756410	total: 559ms	remaining: 2.15s
# 413:	learn: 0.2749403	total: 562ms	remaining: 2.15s
# 414:	learn: 0.2744162	total: 563ms	remaining: 2.15s
# 415:	learn: 0.2739419	total: 564ms	remaining: 2.15s
# 416:	learn: 0.2730381	total: 566ms	remaining: 2.15s
# 417:	learn: 0.2723717	total: 567ms	remaining: 2.15s
# 418:	learn: 0.2719091	total: 568ms	remaining: 2.14s
# 419:	learn: 0.2711203	total: 569ms	remaining: 2.14s
# 420:	learn: 0.2703749	total: 571ms	remaining: 2.14s
# 421:	learn: 0.2695812	total: 572ms	remaining: 2.14s
# 422:	learn: 0.2688032	total: 573ms	remaining: 2.14s
# 423:	learn: 0.2679401	total: 574ms	remaining: 2.13s
# 424:	learn: 0.2672896	total: 576ms	remaining: 2.13s
# 425:	learn: 0.2666045	total: 577ms	remaining: 2.13s
# 426:	learn: 0.2659453	total: 578ms	remaining: 2.13s
# 427:	learn: 0.2653056	total: 580ms	remaining: 2.13s
# 428:	learn: 0.2646470	total: 581ms	remaining: 2.13s
# 429:	learn: 0.2638782	total: 582ms	remaining: 2.13s
# 430:	learn: 0.2634631	total: 583ms	remaining: 2.12s
# 431:	learn: 0.2628986	total: 585ms	remaining: 2.12s
# 432:	learn: 0.2621155	total: 586ms	remaining: 2.12s
# 433:	learn: 0.2613394	total: 587ms	remaining: 2.12s
# 434:	learn: 0.2606897	total: 589ms	remaining: 2.12s
# 435:	learn: 0.2600480	total: 590ms	remaining: 2.12s
# 436:	learn: 0.2593747	total: 591ms	remaining: 2.11s
# 437:	learn: 0.2585781	total: 592ms	remaining: 2.11s
# 438:	learn: 0.2578757	total: 594ms	remaining: 2.11s
# 439:	learn: 0.2574230	total: 595ms	remaining: 2.11s
# 440:	learn: 0.2567792	total: 597ms	remaining: 2.11s
# 441:	learn: 0.2560937	total: 598ms	remaining: 2.11s
# 442:	learn: 0.2554737	total: 599ms	remaining: 2.1s
# 443:	learn: 0.2548134	total: 600ms	remaining: 2.1s
# 444:	learn: 0.2539959	total: 602ms	remaining: 2.1s
# 445:	learn: 0.2534586	total: 603ms	remaining: 2.1s
# 446:	learn: 0.2526139	total: 604ms	remaining: 2.1s
# 447:	learn: 0.2522625	total: 606ms	remaining: 2.1s
# 448:	learn: 0.2515238	total: 607ms	remaining: 2.1s
# 449:	learn: 0.2508381	total: 608ms	remaining: 2.1s
# 450:	learn: 0.2502436	total: 610ms	remaining: 2.09s
# 451:	learn: 0.2496273	total: 611ms	remaining: 2.09s
# 452:	learn: 0.2491097	total: 612ms	remaining: 2.09s
# 453:	learn: 0.2484302	total: 613ms	remaining: 2.09s
# 454:	learn: 0.2478869	total: 615ms	remaining: 2.09s
# 455:	learn: 0.2471250	total: 616ms	remaining: 2.08s
# 456:	learn: 0.2464139	total: 617ms	remaining: 2.08s
# 457:	learn: 0.2458475	total: 618ms	remaining: 2.08s
# 458:	learn: 0.2453057	total: 620ms	remaining: 2.08s
# 459:	learn: 0.2445417	total: 621ms	remaining: 2.08s
# 460:	learn: 0.2441846	total: 622ms	remaining: 2.08s
# 461:	learn: 0.2436743	total: 624ms	remaining: 2.08s
# 462:	learn: 0.2431245	total: 625ms	remaining: 2.07s
# 463:	learn: 0.2423873	total: 626ms	remaining: 2.07s
# 464:	learn: 0.2417390	total: 627ms	remaining: 2.07s
# 465:	learn: 0.2409942	total: 629ms	remaining: 2.07s
# 466:	learn: 0.2405845	total: 630ms	remaining: 2.07s
# 467:	learn: 0.2399517	total: 631ms	remaining: 2.06s
# 468:	learn: 0.2392394	total: 632ms	remaining: 2.06s
# 469:	learn: 0.2387117	total: 634ms	remaining: 2.06s
# 470:	learn: 0.2382754	total: 635ms	remaining: 2.06s
# 471:	learn: 0.2377653	total: 636ms	remaining: 2.06s
# 472:	learn: 0.2370258	total: 637ms	remaining: 2.06s
# 473:	learn: 0.2366364	total: 639ms	remaining: 2.06s
# 474:	learn: 0.2359682	total: 640ms	remaining: 2.05s
# 475:	learn: 0.2352968	total: 641ms	remaining: 2.05s
# 476:	learn: 0.2348731	total: 643ms	remaining: 2.05s
# 477:	learn: 0.2345034	total: 644ms	remaining: 2.05s
# 478:	learn: 0.2337986	total: 645ms	remaining: 2.05s
# 479:	learn: 0.2332459	total: 646ms	remaining: 2.05s
# 480:	learn: 0.2326758	total: 648ms	remaining: 2.04s
# 481:	learn: 0.2319506	total: 649ms	remaining: 2.04s
# 482:	learn: 0.2313814	total: 650ms	remaining: 2.04s
# 483:	learn: 0.2307125	total: 651ms	remaining: 2.04s
# 484:	learn: 0.2300466	total: 653ms	remaining: 2.04s
# 485:	learn: 0.2293979	total: 654ms	remaining: 2.04s
# 486:	learn: 0.2287961	total: 655ms	remaining: 2.04s
# 487:	learn: 0.2283060	total: 657ms	remaining: 2.03s
# 488:	learn: 0.2277502	total: 658ms	remaining: 2.03s
# 489:	learn: 0.2272784	total: 659ms	remaining: 2.03s
# 490:	learn: 0.2268619	total: 660ms	remaining: 2.03s
# 491:	learn: 0.2262172	total: 661ms	remaining: 2.03s
# 492:	learn: 0.2260348	total: 662ms	remaining: 2.02s
# 493:	learn: 0.2254693	total: 663ms	remaining: 2.02s
# 494:	learn: 0.2249072	total: 665ms	remaining: 2.02s
# 495:	learn: 0.2242843	total: 666ms	remaining: 2.02s
# 496:	learn: 0.2237861	total: 667ms	remaining: 2.02s
# 497:	learn: 0.2234680	total: 668ms	remaining: 2.02s
# 498:	learn: 0.2228943	total: 670ms	remaining: 2.01s
# 499:	learn: 0.2222726	total: 671ms	remaining: 2.01s
# 500:	learn: 0.2218060	total: 672ms	remaining: 2.01s
# 501:	learn: 0.2214363	total: 674ms	remaining: 2.01s
# 502:	learn: 0.2209387	total: 675ms	remaining: 2.01s
# 503:	learn: 0.2204001	total: 676ms	remaining: 2.01s
# 504:	learn: 0.2197722	total: 677ms	remaining: 2s
# 505:	learn: 0.2193751	total: 679ms	remaining: 2s
# 506:	learn: 0.2188907	total: 680ms	remaining: 2s
# 507:	learn: 0.2183943	total: 681ms	remaining: 2s
# 508:	learn: 0.2181748	total: 683ms	remaining: 2s
# 509:	learn: 0.2175801	total: 684ms	remaining: 2s
# 510:	learn: 0.2170811	total: 685ms	remaining: 2s
# 511:	learn: 0.2167319	total: 686ms	remaining: 1.99s
# 512:	learn: 0.2161174	total: 688ms	remaining: 1.99s
# 513:	learn: 0.2154945	total: 689ms	remaining: 1.99s
# 514:	learn: 0.2149949	total: 690ms	remaining: 1.99s
# 515:	learn: 0.2145417	total: 691ms	remaining: 1.99s
# 516:	learn: 0.2141005	total: 693ms	remaining: 1.99s
# 517:	learn: 0.2136426	total: 694ms	remaining: 1.98s
# 518:	learn: 0.2131340	total: 695ms	remaining: 1.98s
# 519:	learn: 0.2126250	total: 696ms	remaining: 1.98s
# 520:	learn: 0.2121112	total: 698ms	remaining: 1.98s
# 521:	learn: 0.2116651	total: 699ms	remaining: 1.98s
# 522:	learn: 0.2110495	total: 700ms	remaining: 1.98s
# 523:	learn: 0.2105857	total: 702ms	remaining: 1.98s
# 524:	learn: 0.2100820	total: 703ms	remaining: 1.97s
# 525:	learn: 0.2096466	total: 704ms	remaining: 1.97s
# 526:	learn: 0.2092423	total: 705ms	remaining: 1.97s
# 527:	learn: 0.2085768	total: 707ms	remaining: 1.97s
# 528:	learn: 0.2081090	total: 708ms	remaining: 1.97s
# 529:	learn: 0.2076649	total: 709ms	remaining: 1.97s
# 530:	learn: 0.2072159	total: 710ms	remaining: 1.97s
# 531:	learn: 0.2067463	total: 712ms	remaining: 1.96s
# 532:	learn: 0.2063867	total: 713ms	remaining: 1.96s
# 533:	learn: 0.2059234	total: 714ms	remaining: 1.96s
# 534:	learn: 0.2054886	total: 716ms	remaining: 1.96s
# 535:	learn: 0.2051159	total: 717ms	remaining: 1.96s
# 536:	learn: 0.2046157	total: 718ms	remaining: 1.96s
# 537:	learn: 0.2041660	total: 719ms	remaining: 1.95s
# 538:	learn: 0.2036418	total: 720ms	remaining: 1.95s
# 539:	learn: 0.2032678	total: 721ms	remaining: 1.95s
# 540:	learn: 0.2029875	total: 723ms	remaining: 1.95s
# 541:	learn: 0.2024130	total: 724ms	remaining: 1.95s
# 542:	learn: 0.2018788	total: 725ms	remaining: 1.95s
# 543:	learn: 0.2015786	total: 727ms	remaining: 1.94s
# 544:	learn: 0.2010413	total: 728ms	remaining: 1.94s
# 545:	learn: 0.2006028	total: 729ms	remaining: 1.94s
# 546:	learn: 0.2001585	total: 731ms	remaining: 1.94s
# 547:	learn: 0.1995642	total: 732ms	remaining: 1.94s
# 548:	learn: 0.1991560	total: 733ms	remaining: 1.94s
# 549:	learn: 0.1986338	total: 735ms	remaining: 1.94s
# 550:	learn: 0.1981797	total: 736ms	remaining: 1.94s
# 551:	learn: 0.1975589	total: 737ms	remaining: 1.93s
# 552:	learn: 0.1970899	total: 738ms	remaining: 1.93s
# 553:	learn: 0.1966716	total: 740ms	remaining: 1.93s
# 554:	learn: 0.1962376	total: 742ms	remaining: 1.93s
# 555:	learn: 0.1958170	total: 744ms	remaining: 1.93s
# 556:	learn: 0.1954779	total: 747ms	remaining: 1.94s
# 557:	learn: 0.1951342	total: 749ms	remaining: 1.93s
# 558:	learn: 0.1946786	total: 750ms	remaining: 1.93s
# 559:	learn: 0.1941245	total: 751ms	remaining: 1.93s
# 560:	learn: 0.1936490	total: 752ms	remaining: 1.93s
# 561:	learn: 0.1932762	total: 753ms	remaining: 1.93s
# 562:	learn: 0.1928282	total: 754ms	remaining: 1.93s
# 563:	learn: 0.1922940	total: 756ms	remaining: 1.92s
# 564:	learn: 0.1918830	total: 757ms	remaining: 1.92s
# 565:	learn: 0.1914800	total: 758ms	remaining: 1.92s
# 566:	learn: 0.1910293	total: 760ms	remaining: 1.92s
# 567:	learn: 0.1905886	total: 761ms	remaining: 1.92s
# 568:	learn: 0.1902907	total: 762ms	remaining: 1.92s
# 569:	learn: 0.1898460	total: 763ms	remaining: 1.91s
# 570:	learn: 0.1895355	total: 765ms	remaining: 1.91s
# 571:	learn: 0.1890767	total: 766ms	remaining: 1.91s
# 572:	learn: 0.1887008	total: 767ms	remaining: 1.91s
# 573:	learn: 0.1882995	total: 768ms	remaining: 1.91s
# 574:	learn: 0.1880394	total: 770ms	remaining: 1.91s
# 575:	learn: 0.1875786	total: 771ms	remaining: 1.91s
# 576:	learn: 0.1871131	total: 772ms	remaining: 1.9s
# 577:	learn: 0.1866256	total: 774ms	remaining: 1.9s
# 578:	learn: 0.1862207	total: 775ms	remaining: 1.9s
# 579:	learn: 0.1857587	total: 777ms	remaining: 1.9s
# 580:	learn: 0.1854660	total: 778ms	remaining: 1.9s
# 581:	learn: 0.1851001	total: 779ms	remaining: 1.9s
# 582:	learn: 0.1847282	total: 780ms	remaining: 1.9s
# 583:	learn: 0.1843577	total: 781ms	remaining: 1.89s
# 584:	learn: 0.1840202	total: 783ms	remaining: 1.89s
# 585:	learn: 0.1836427	total: 784ms	remaining: 1.89s
# 586:	learn: 0.1833324	total: 785ms	remaining: 1.89s
# 587:	learn: 0.1828408	total: 787ms	remaining: 1.89s
# 588:	learn: 0.1824802	total: 788ms	remaining: 1.89s
# 589:	learn: 0.1821257	total: 789ms	remaining: 1.89s
# 590:	learn: 0.1816557	total: 790ms	remaining: 1.88s
# 591:	learn: 0.1812002	total: 792ms	remaining: 1.88s
# 592:	learn: 0.1808124	total: 793ms	remaining: 1.88s
# 593:	learn: 0.1805417	total: 794ms	remaining: 1.88s
# 594:	learn: 0.1801176	total: 797ms	remaining: 1.88s
# 595:	learn: 0.1799007	total: 799ms	remaining: 1.88s
# 596:	learn: 0.1796045	total: 800ms	remaining: 1.88s
# 597:	learn: 0.1792854	total: 802ms	remaining: 1.88s
# 598:	learn: 0.1789887	total: 803ms	remaining: 1.88s
# 599:	learn: 0.1786552	total: 805ms	remaining: 1.88s
# 600:	learn: 0.1782184	total: 806ms	remaining: 1.88s
# 601:	learn: 0.1777905	total: 807ms	remaining: 1.87s
# 602:	learn: 0.1774706	total: 808ms	remaining: 1.87s
# 603:	learn: 0.1770639	total: 809ms	remaining: 1.87s
# 604:	learn: 0.1767197	total: 811ms	remaining: 1.87s
# 605:	learn: 0.1764028	total: 812ms	remaining: 1.87s
# 606:	learn: 0.1760562	total: 813ms	remaining: 1.87s
# 607:	learn: 0.1758289	total: 814ms	remaining: 1.86s
# 608:	learn: 0.1754688	total: 816ms	remaining: 1.86s
# 609:	learn: 0.1750853	total: 817ms	remaining: 1.86s
# 610:	learn: 0.1747682	total: 818ms	remaining: 1.86s
# 611:	learn: 0.1744444	total: 819ms	remaining: 1.86s
# 612:	learn: 0.1740142	total: 821ms	remaining: 1.86s
# 613:	learn: 0.1736386	total: 822ms	remaining: 1.85s
# 614:	learn: 0.1732831	total: 823ms	remaining: 1.85s
# 615:	learn: 0.1729696	total: 825ms	remaining: 1.85s
# 616:	learn: 0.1727003	total: 826ms	remaining: 1.85s
# 617:	learn: 0.1724318	total: 827ms	remaining: 1.85s
# 618:	learn: 0.1720000	total: 828ms	remaining: 1.85s
# 619:	learn: 0.1715782	total: 830ms	remaining: 1.85s
# 620:	learn: 0.1712178	total: 831ms	remaining: 1.84s
# 621:	learn: 0.1708309	total: 832ms	remaining: 1.84s
# 622:	learn: 0.1704362	total: 834ms	remaining: 1.84s
# 623:	learn: 0.1700872	total: 835ms	remaining: 1.84s
# 624:	learn: 0.1697437	total: 836ms	remaining: 1.84s
# 625:	learn: 0.1694493	total: 837ms	remaining: 1.84s
# 626:	learn: 0.1692528	total: 838ms	remaining: 1.84s
# 627:	learn: 0.1689437	total: 839ms	remaining: 1.83s
# 628:	learn: 0.1686598	total: 841ms	remaining: 1.83s
# 629:	learn: 0.1682583	total: 842ms	remaining: 1.83s
# 630:	learn: 0.1679509	total: 843ms	remaining: 1.83s
# 631:	learn: 0.1676328	total: 844ms	remaining: 1.82s
# 632:	learn: 0.1672540	total: 845ms	remaining: 1.82s
# 633:	learn: 0.1669891	total: 846ms	remaining: 1.82s
# 634:	learn: 0.1667085	total: 847ms	remaining: 1.82s
# 635:	learn: 0.1664468	total: 848ms	remaining: 1.82s
# 636:	learn: 0.1661279	total: 849ms	remaining: 1.82s
# 637:	learn: 0.1658865	total: 850ms	remaining: 1.81s
# 638:	learn: 0.1656307	total: 851ms	remaining: 1.81s
# 639:	learn: 0.1652932	total: 853ms	remaining: 1.81s
# 640:	learn: 0.1649709	total: 854ms	remaining: 1.81s
# 641:	learn: 0.1646684	total: 855ms	remaining: 1.81s
# 642:	learn: 0.1644389	total: 857ms	remaining: 1.81s
# 643:	learn: 0.1641362	total: 858ms	remaining: 1.81s
# 644:	learn: 0.1639074	total: 859ms	remaining: 1.8s
# 645:	learn: 0.1636598	total: 860ms	remaining: 1.8s
# 646:	learn: 0.1633917	total: 862ms	remaining: 1.8s
# 647:	learn: 0.1630151	total: 863ms	remaining: 1.8s
# 648:	learn: 0.1627486	total: 864ms	remaining: 1.8s
# 649:	learn: 0.1624912	total: 866ms	remaining: 1.8s
# 650:	learn: 0.1621139	total: 867ms	remaining: 1.8s
# 651:	learn: 0.1617388	total: 868ms	remaining: 1.79s
# 652:	learn: 0.1613815	total: 869ms	remaining: 1.79s
# 653:	learn: 0.1611163	total: 871ms	remaining: 1.79s
# 654:	learn: 0.1608187	total: 872ms	remaining: 1.79s
# 655:	learn: 0.1606231	total: 873ms	remaining: 1.79s
# 656:	learn: 0.1602746	total: 874ms	remaining: 1.79s
# 657:	learn: 0.1599108	total: 876ms	remaining: 1.78s
# 658:	learn: 0.1596122	total: 877ms	remaining: 1.78s
# 659:	learn: 0.1592392	total: 878ms	remaining: 1.78s
# 660:	learn: 0.1589183	total: 880ms	remaining: 1.78s
# 661:	learn: 0.1587164	total: 881ms	remaining: 1.78s
# 662:	learn: 0.1584618	total: 883ms	remaining: 1.78s
# 663:	learn: 0.1582237	total: 884ms	remaining: 1.78s
# 664:	learn: 0.1578197	total: 886ms	remaining: 1.78s
# 665:	learn: 0.1575966	total: 887ms	remaining: 1.78s
# 666:	learn: 0.1572970	total: 888ms	remaining: 1.77s
# 667:	learn: 0.1569458	total: 890ms	remaining: 1.77s
# 668:	learn: 0.1566094	total: 891ms	remaining: 1.77s
# 669:	learn: 0.1562435	total: 893ms	remaining: 1.77s
# 670:	learn: 0.1559083	total: 894ms	remaining: 1.77s
# 671:	learn: 0.1556271	total: 896ms	remaining: 1.77s
# 672:	learn: 0.1552861	total: 897ms	remaining: 1.77s
# 673:	learn: 0.1549908	total: 898ms	remaining: 1.77s
# 674:	learn: 0.1546453	total: 900ms	remaining: 1.77s
# 675:	learn: 0.1543528	total: 901ms	remaining: 1.76s
# 676:	learn: 0.1540920	total: 903ms	remaining: 1.76s
# 677:	learn: 0.1537582	total: 904ms	remaining: 1.76s
# 678:	learn: 0.1534233	total: 906ms	remaining: 1.76s
# 679:	learn: 0.1530920	total: 907ms	remaining: 1.76s
# 680:	learn: 0.1528040	total: 909ms	remaining: 1.76s
# 681:	learn: 0.1525511	total: 910ms	remaining: 1.76s
# 682:	learn: 0.1522877	total: 911ms	remaining: 1.76s
# 683:	learn: 0.1520251	total: 913ms	remaining: 1.76s
# 684:	learn: 0.1517083	total: 914ms	remaining: 1.75s
# 685:	learn: 0.1513872	total: 916ms	remaining: 1.75s
# 686:	learn: 0.1512270	total: 917ms	remaining: 1.75s
# 687:	learn: 0.1509815	total: 919ms	remaining: 1.75s
# 688:	learn: 0.1506207	total: 923ms	remaining: 1.75s
# 689:	learn: 0.1503105	total: 925ms	remaining: 1.75s
# 690:	learn: 0.1500337	total: 926ms	remaining: 1.75s
# 691:	learn: 0.1498671	total: 928ms	remaining: 1.75s
# 692:	learn: 0.1496421	total: 929ms	remaining: 1.75s
# 693:	learn: 0.1493732	total: 930ms	remaining: 1.75s
# 694:	learn: 0.1490642	total: 931ms	remaining: 1.75s
# 695:	learn: 0.1486911	total: 932ms	remaining: 1.75s
# 696:	learn: 0.1484127	total: 933ms	remaining: 1.74s
# 697:	learn: 0.1481036	total: 934ms	remaining: 1.74s
# 698:	learn: 0.1477908	total: 935ms	remaining: 1.74s
# 699:	learn: 0.1474645	total: 936ms	remaining: 1.74s
# 700:	learn: 0.1472010	total: 938ms	remaining: 1.74s
# 701:	learn: 0.1469724	total: 939ms	remaining: 1.74s
# 702:	learn: 0.1466629	total: 940ms	remaining: 1.73s
# 703:	learn: 0.1463467	total: 941ms	remaining: 1.73s
# 704:	learn: 0.1461514	total: 943ms	remaining: 1.73s
# 705:	learn: 0.1458317	total: 944ms	remaining: 1.73s
# 706:	learn: 0.1455722	total: 945ms	remaining: 1.73s
# 707:	learn: 0.1453603	total: 946ms	remaining: 1.73s
# 708:	learn: 0.1450677	total: 948ms	remaining: 1.73s
# 709:	learn: 0.1448106	total: 949ms	remaining: 1.72s
# 710:	learn: 0.1445627	total: 950ms	remaining: 1.72s
# 711:	learn: 0.1443377	total: 952ms	remaining: 1.72s
# 712:	learn: 0.1441257	total: 953ms	remaining: 1.72s
# 713:	learn: 0.1438646	total: 954ms	remaining: 1.72s
# 714:	learn: 0.1436942	total: 955ms	remaining: 1.72s
# 715:	learn: 0.1434495	total: 957ms	remaining: 1.72s
# 716:	learn: 0.1431782	total: 958ms	remaining: 1.71s
# 717:	learn: 0.1430689	total: 959ms	remaining: 1.71s
# 718:	learn: 0.1428085	total: 960ms	remaining: 1.71s
# 719:	learn: 0.1425383	total: 962ms	remaining: 1.71s
# 720:	learn: 0.1423348	total: 963ms	remaining: 1.71s
# 721:	learn: 0.1421297	total: 964ms	remaining: 1.71s
# 722:	learn: 0.1418540	total: 965ms	remaining: 1.71s
# 723:	learn: 0.1416217	total: 967ms	remaining: 1.7s
# 724:	learn: 0.1413709	total: 968ms	remaining: 1.7s
# 725:	learn: 0.1412486	total: 969ms	remaining: 1.7s
# 726:	learn: 0.1410290	total: 970ms	remaining: 1.7s
# 727:	learn: 0.1408255	total: 972ms	remaining: 1.7s
# 728:	learn: 0.1405343	total: 973ms	remaining: 1.7s
# 729:	learn: 0.1404293	total: 974ms	remaining: 1.69s
# 730:	learn: 0.1402511	total: 975ms	remaining: 1.69s
# 731:	learn: 0.1400883	total: 977ms	remaining: 1.69s
# 732:	learn: 0.1398150	total: 978ms	remaining: 1.69s
# 733:	learn: 0.1395151	total: 979ms	remaining: 1.69s
# 734:	learn: 0.1392752	total: 980ms	remaining: 1.69s
# 735:	learn: 0.1390611	total: 982ms	remaining: 1.69s
# 736:	learn: 0.1388112	total: 983ms	remaining: 1.68s
# 737:	learn: 0.1385497	total: 984ms	remaining: 1.68s
# 738:	learn: 0.1382458	total: 986ms	remaining: 1.68s
# 739:	learn: 0.1380327	total: 987ms	remaining: 1.68s
# 740:	learn: 0.1378387	total: 988ms	remaining: 1.68s
# 741:	learn: 0.1377092	total: 989ms	remaining: 1.68s
# 742:	learn: 0.1374095	total: 991ms	remaining: 1.68s
# 743:	learn: 0.1371729	total: 992ms	remaining: 1.67s
# 744:	learn: 0.1369174	total: 993ms	remaining: 1.67s
# 745:	learn: 0.1366912	total: 995ms	remaining: 1.67s
# 746:	learn: 0.1365000	total: 996ms	remaining: 1.67s
# 747:	learn: 0.1362577	total: 997ms	remaining: 1.67s
# 748:	learn: 0.1360029	total: 999ms	remaining: 1.67s
# 749:	learn: 0.1357666	total: 1s	remaining: 1.67s
# 750:	learn: 0.1355389	total: 1s	remaining: 1.67s
# 751:	learn: 0.1352700	total: 1s	remaining: 1.66s
# 752:	learn: 0.1350386	total: 1s	remaining: 1.66s
# 753:	learn: 0.1347163	total: 1s	remaining: 1.66s
# 754:	learn: 0.1345395	total: 1.01s	remaining: 1.66s
# 755:	learn: 0.1343251	total: 1.01s	remaining: 1.66s
# 756:	learn: 0.1340692	total: 1.01s	remaining: 1.66s
# 757:	learn: 0.1338879	total: 1.01s	remaining: 1.66s
# 758:	learn: 0.1336868	total: 1.01s	remaining: 1.65s
# 759:	learn: 0.1334371	total: 1.01s	remaining: 1.65s
# 760:	learn: 0.1332615	total: 1.01s	remaining: 1.65s
# 761:	learn: 0.1331038	total: 1.01s	remaining: 1.65s
# 762:	learn: 0.1329633	total: 1.02s	remaining: 1.65s
# 763:	learn: 0.1327343	total: 1.02s	remaining: 1.65s
# 764:	learn: 0.1325134	total: 1.02s	remaining: 1.65s
# 765:	learn: 0.1322327	total: 1.02s	remaining: 1.64s
# 766:	learn: 0.1321164	total: 1.02s	remaining: 1.64s
# 767:	learn: 0.1319491	total: 1.02s	remaining: 1.64s
# 768:	learn: 0.1316775	total: 1.02s	remaining: 1.64s
# 769:	learn: 0.1314003	total: 1.02s	remaining: 1.64s
# 770:	learn: 0.1311713	total: 1.03s	remaining: 1.64s
# 771:	learn: 0.1309729	total: 1.03s	remaining: 1.63s
# 772:	learn: 0.1307811	total: 1.03s	remaining: 1.63s
# 773:	learn: 0.1305944	total: 1.03s	remaining: 1.63s
# 774:	learn: 0.1304189	total: 1.03s	remaining: 1.63s
# 775:	learn: 0.1301526	total: 1.03s	remaining: 1.63s
# 776:	learn: 0.1299185	total: 1.03s	remaining: 1.63s
# 777:	learn: 0.1296985	total: 1.03s	remaining: 1.63s
# 778:	learn: 0.1294508	total: 1.04s	remaining: 1.62s
# 779:	learn: 0.1292131	total: 1.04s	remaining: 1.62s
# 780:	learn: 0.1290248	total: 1.04s	remaining: 1.62s
# 781:	learn: 0.1288418	total: 1.04s	remaining: 1.62s
# 782:	learn: 0.1286308	total: 1.04s	remaining: 1.62s
# 783:	learn: 0.1284183	total: 1.04s	remaining: 1.62s
# 784:	learn: 0.1282485	total: 1.04s	remaining: 1.61s
# 785:	learn: 0.1280567	total: 1.04s	remaining: 1.61s
# 786:	learn: 0.1278501	total: 1.05s	remaining: 1.61s
# 787:	learn: 0.1277488	total: 1.05s	remaining: 1.61s
# 788:	learn: 0.1275991	total: 1.05s	remaining: 1.61s
# 789:	learn: 0.1273240	total: 1.05s	remaining: 1.61s
# 790:	learn: 0.1271674	total: 1.05s	remaining: 1.61s
# 791:	learn: 0.1269131	total: 1.05s	remaining: 1.6s
# 792:	learn: 0.1267302	total: 1.05s	remaining: 1.6s
# 793:	learn: 0.1265598	total: 1.05s	remaining: 1.6s
# 794:	learn: 0.1264820	total: 1.06s	remaining: 1.6s
# 795:	learn: 0.1262785	total: 1.06s	remaining: 1.6s
# 796:	learn: 0.1260691	total: 1.06s	remaining: 1.6s
# 797:	learn: 0.1257951	total: 1.06s	remaining: 1.6s
# 798:	learn: 0.1256327	total: 1.06s	remaining: 1.59s
# 799:	learn: 0.1254700	total: 1.06s	remaining: 1.59s
# 800:	learn: 0.1253410	total: 1.06s	remaining: 1.59s
# 801:	learn: 0.1251441	total: 1.06s	remaining: 1.59s
# 802:	learn: 0.1250552	total: 1.06s	remaining: 1.59s
# 803:	learn: 0.1249549	total: 1.07s	remaining: 1.59s
# 804:	learn: 0.1248741	total: 1.07s	remaining: 1.58s
# 805:	learn: 0.1247163	total: 1.07s	remaining: 1.58s
# 806:	learn: 0.1244987	total: 1.07s	remaining: 1.58s
# 807:	learn: 0.1242790	total: 1.07s	remaining: 1.58s
# 808:	learn: 0.1241619	total: 1.07s	remaining: 1.58s
# 809:	learn: 0.1240092	total: 1.07s	remaining: 1.58s
# 810:	learn: 0.1238336	total: 1.07s	remaining: 1.58s
# 811:	learn: 0.1236379	total: 1.08s	remaining: 1.57s
# 812:	learn: 0.1234350	total: 1.08s	remaining: 1.57s
# 813:	learn: 0.1232587	total: 1.08s	remaining: 1.57s
# 814:	learn: 0.1230907	total: 1.08s	remaining: 1.57s
# 815:	learn: 0.1229298	total: 1.08s	remaining: 1.57s
# 816:	learn: 0.1226872	total: 1.08s	remaining: 1.57s
# 817:	learn: 0.1224779	total: 1.08s	remaining: 1.57s
# 818:	learn: 0.1223298	total: 1.08s	remaining: 1.56s
# 819:	learn: 0.1221918	total: 1.09s	remaining: 1.56s
# 820:	learn: 0.1219826	total: 1.09s	remaining: 1.56s
# 821:	learn: 0.1217513	total: 1.09s	remaining: 1.56s
# 822:	learn: 0.1216356	total: 1.09s	remaining: 1.56s
# 823:	learn: 0.1214474	total: 1.09s	remaining: 1.56s
# 824:	learn: 0.1212624	total: 1.09s	remaining: 1.56s
# 825:	learn: 0.1210609	total: 1.09s	remaining: 1.55s
# 826:	learn: 0.1209120	total: 1.09s	remaining: 1.55s
# 827:	learn: 0.1207293	total: 1.1s	remaining: 1.55s
# 828:	learn: 0.1206137	total: 1.1s	remaining: 1.55s
# 829:	learn: 0.1203843	total: 1.1s	remaining: 1.55s
# 830:	learn: 0.1201315	total: 1.1s	remaining: 1.55s
# 831:	learn: 0.1199955	total: 1.1s	remaining: 1.55s
# 832:	learn: 0.1197764	total: 1.1s	remaining: 1.55s
# 833:	learn: 0.1196046	total: 1.1s	remaining: 1.54s
# 834:	learn: 0.1194668	total: 1.11s	remaining: 1.55s
# 835:	learn: 0.1193104	total: 1.11s	remaining: 1.55s
# 836:	learn: 0.1191591	total: 1.11s	remaining: 1.55s
# 837:	learn: 0.1190151	total: 1.11s	remaining: 1.54s
# 838:	learn: 0.1188983	total: 1.12s	remaining: 1.54s
# 839:	learn: 0.1187029	total: 1.12s	remaining: 1.54s
# 840:	learn: 0.1185331	total: 1.12s	remaining: 1.54s
# 841:	learn: 0.1183787	total: 1.12s	remaining: 1.54s
# 842:	learn: 0.1181949	total: 1.12s	remaining: 1.54s
# 843:	learn: 0.1180204	total: 1.12s	remaining: 1.54s
# 844:	learn: 0.1177871	total: 1.12s	remaining: 1.54s
# 845:	learn: 0.1176262	total: 1.13s	remaining: 1.53s
# 846:	learn: 0.1174361	total: 1.13s	remaining: 1.53s
# 847:	learn: 0.1172509	total: 1.13s	remaining: 1.53s
# 848:	learn: 0.1171330	total: 1.13s	remaining: 1.53s
# 849:	learn: 0.1169712	total: 1.13s	remaining: 1.53s
# 850:	learn: 0.1167489	total: 1.13s	remaining: 1.53s
# 851:	learn: 0.1165396	total: 1.13s	remaining: 1.53s
# 852:	learn: 0.1163426	total: 1.13s	remaining: 1.52s
# 853:	learn: 0.1161942	total: 1.14s	remaining: 1.52s
# 854:	learn: 0.1160278	total: 1.14s	remaining: 1.52s
# 855:	learn: 0.1158408	total: 1.14s	remaining: 1.52s
# 856:	learn: 0.1156850	total: 1.14s	remaining: 1.52s
# 857:	learn: 0.1155312	total: 1.14s	remaining: 1.52s
# 858:	learn: 0.1154535	total: 1.14s	remaining: 1.52s
# 859:	learn: 0.1152973	total: 1.14s	remaining: 1.52s
# 860:	learn: 0.1151714	total: 1.15s	remaining: 1.51s
# 861:	learn: 0.1149928	total: 1.15s	remaining: 1.51s
# 862:	learn: 0.1148054	total: 1.15s	remaining: 1.51s
# 863:	learn: 0.1145659	total: 1.15s	remaining: 1.51s
# 864:	learn: 0.1144164	total: 1.15s	remaining: 1.51s
# 865:	learn: 0.1142274	total: 1.15s	remaining: 1.51s
# 866:	learn: 0.1140343	total: 1.15s	remaining: 1.51s
# 867:	learn: 0.1138608	total: 1.16s	remaining: 1.51s
# 868:	learn: 0.1137206	total: 1.16s	remaining: 1.5s
# 869:	learn: 0.1135267	total: 1.16s	remaining: 1.5s
# 870:	learn: 0.1133220	total: 1.16s	remaining: 1.5s
# 871:	learn: 0.1132199	total: 1.16s	remaining: 1.5s
# 872:	learn: 0.1130496	total: 1.16s	remaining: 1.5s
# 873:	learn: 0.1128801	total: 1.16s	remaining: 1.5s
# 874:	learn: 0.1127369	total: 1.16s	remaining: 1.5s
# 875:	learn: 0.1125896	total: 1.17s	remaining: 1.5s
# 876:	learn: 0.1124374	total: 1.17s	remaining: 1.49s
# 877:	learn: 0.1122636	total: 1.17s	remaining: 1.49s
# 878:	learn: 0.1121163	total: 1.17s	remaining: 1.49s
# 879:	learn: 0.1119513	total: 1.17s	remaining: 1.49s
# 880:	learn: 0.1117637	total: 1.17s	remaining: 1.49s
# 881:	learn: 0.1116050	total: 1.17s	remaining: 1.49s
# 882:	learn: 0.1114392	total: 1.18s	remaining: 1.49s
# 883:	learn: 0.1113438	total: 1.18s	remaining: 1.49s
# 884:	learn: 0.1112190	total: 1.18s	remaining: 1.48s
# 885:	learn: 0.1110421	total: 1.18s	remaining: 1.48s
# 886:	learn: 0.1108165	total: 1.18s	remaining: 1.48s
# 887:	learn: 0.1106830	total: 1.18s	remaining: 1.48s
# 888:	learn: 0.1105162	total: 1.18s	remaining: 1.48s
# 889:	learn: 0.1103362	total: 1.18s	remaining: 1.48s
# 890:	learn: 0.1101426	total: 1.19s	remaining: 1.48s
# 891:	learn: 0.1099758	total: 1.19s	remaining: 1.47s
# 892:	learn: 0.1098201	total: 1.19s	remaining: 1.47s
# 893:	learn: 0.1096267	total: 1.19s	remaining: 1.47s
# 894:	learn: 0.1095000	total: 1.19s	remaining: 1.47s
# 895:	learn: 0.1093744	total: 1.19s	remaining: 1.47s
# 896:	learn: 0.1091915	total: 1.19s	remaining: 1.47s
# 897:	learn: 0.1090517	total: 1.19s	remaining: 1.47s
# 898:	learn: 0.1089252	total: 1.2s	remaining: 1.46s
# 899:	learn: 0.1087493	total: 1.2s	remaining: 1.46s
# 900:	learn: 0.1085977	total: 1.2s	remaining: 1.46s
# 901:	learn: 0.1084407	total: 1.2s	remaining: 1.46s
# 902:	learn: 0.1083188	total: 1.2s	remaining: 1.46s
# 903:	learn: 0.1081982	total: 1.2s	remaining: 1.46s
# 904:	learn: 0.1080261	total: 1.2s	remaining: 1.46s
# 905:	learn: 0.1078939	total: 1.21s	remaining: 1.46s
# 906:	learn: 0.1077497	total: 1.21s	remaining: 1.45s
# 907:	learn: 0.1076067	total: 1.21s	remaining: 1.45s
# 908:	learn: 0.1074773	total: 1.21s	remaining: 1.45s
# 909:	learn: 0.1073678	total: 1.21s	remaining: 1.45s
# 910:	learn: 0.1072423	total: 1.21s	remaining: 1.45s
# 911:	learn: 0.1071294	total: 1.21s	remaining: 1.45s
# 912:	learn: 0.1069874	total: 1.21s	remaining: 1.45s
# 913:	learn: 0.1067913	total: 1.22s	remaining: 1.44s
# 914:	learn: 0.1066575	total: 1.22s	remaining: 1.44s
# 915:	learn: 0.1065386	total: 1.22s	remaining: 1.44s
# 916:	learn: 0.1064080	total: 1.22s	remaining: 1.44s
# 917:	learn: 0.1062648	total: 1.22s	remaining: 1.44s
# 918:	learn: 0.1061764	total: 1.22s	remaining: 1.44s
# 919:	learn: 0.1060412	total: 1.22s	remaining: 1.44s
# 920:	learn: 0.1059088	total: 1.22s	remaining: 1.43s
# 921:	learn: 0.1058202	total: 1.23s	remaining: 1.43s
# 922:	learn: 0.1056758	total: 1.23s	remaining: 1.43s
# 923:	learn: 0.1055206	total: 1.23s	remaining: 1.43s
# 924:	learn: 0.1053950	total: 1.23s	remaining: 1.43s
# 925:	learn: 0.1052560	total: 1.23s	remaining: 1.43s
# ...
# 1700:	learn: 0.0500252	total: 2.26s	remaining: 398ms
# 1701:	learn: 0.0499893	total: 2.26s	remaining: 396ms
# 1702:	learn: 0.0499566	total: 2.27s	remaining: 395ms
# 1703:	learn: 0.0499336	total: 2.27s	remaining: 394ms
# 1704:	learn: 0.0498937	total: 2.27s	remaining: 392ms
# 1705:	learn: 0.0498687	total: 2.27s	remaining: 391ms
# 1706:	learn: 0.0498348	total: 2.27s	remaining: 390ms
# 1707:	learn: 0.0498051	total: 2.27s	remaining: 388ms
# 1708:	learn: 0.0497689	total: 2.27s	remaining: 387ms
# 1709:	learn: 0.0497345	total: 2.27s	remaining: 386ms
# 1710:	learn: 0.0497017	total: 2.27s	remaining: 384ms
# 1711:	learn: 0.0496588	total: 2.28s	remaining: 383ms
# 1712:	learn: 0.0496250	total: 2.28s	remaining: 382ms
# 1713:	learn: 0.0495967	total: 2.28s	remaining: 380ms
# 1714:	learn: 0.0495573	total: 2.28s	remaining: 379ms
# 1715:	learn: 0.0495385	total: 2.28s	remaining: 378ms
# 1716:	learn: 0.0494985	total: 2.28s	remaining: 376ms
# 1717:	learn: 0.0494741	total: 2.28s	remaining: 375ms
# 1718:	learn: 0.0494400	total: 2.28s	remaining: 374ms
# 1719:	learn: 0.0494027	total: 2.29s	remaining: 372ms
# 1720:	learn: 0.0493656	total: 2.29s	remaining: 371ms
# 1721:	learn: 0.0493362	total: 2.29s	remaining: 369ms
# 1722:	learn: 0.0493097	total: 2.29s	remaining: 368ms
# 1723:	learn: 0.0492739	total: 2.29s	remaining: 367ms
# 1724:	learn: 0.0492222	total: 2.29s	remaining: 365ms
# 1725:	learn: 0.0491858	total: 2.29s	remaining: 364ms
# 1726:	learn: 0.0491541	total: 2.29s	remaining: 363ms
# 1727:	learn: 0.0491178	total: 2.3s	remaining: 361ms
# 1728:	learn: 0.0490856	total: 2.3s	remaining: 360ms
# 1729:	learn: 0.0490506	total: 2.3s	remaining: 359ms
# 1730:	learn: 0.0490222	total: 2.3s	remaining: 357ms
# 1731:	learn: 0.0489858	total: 2.3s	remaining: 356ms
# 1732:	learn: 0.0489522	total: 2.3s	remaining: 355ms
# 1733:	learn: 0.0489153	total: 2.3s	remaining: 353ms
# 1734:	learn: 0.0488936	total: 2.3s	remaining: 352ms
# 1735:	learn: 0.0488658	total: 2.31s	remaining: 351ms
# 1736:	learn: 0.0488216	total: 2.31s	remaining: 349ms
# 1737:	learn: 0.0487927	total: 2.31s	remaining: 348ms
# 1738:	learn: 0.0487615	total: 2.31s	remaining: 347ms
# 1739:	learn: 0.0487165	total: 2.31s	remaining: 345ms
# 1740:	learn: 0.0486816	total: 2.31s	remaining: 344ms
# 1741:	learn: 0.0486410	total: 2.31s	remaining: 343ms
# 1742:	learn: 0.0486030	total: 2.31s	remaining: 341ms
# 1743:	learn: 0.0485752	total: 2.31s	remaining: 340ms
# 1744:	learn: 0.0485420	total: 2.32s	remaining: 339ms
# 1745:	learn: 0.0485134	total: 2.32s	remaining: 338ms
# 1746:	learn: 0.0484632	total: 2.32s	remaining: 336ms
# 1747:	learn: 0.0484291	total: 2.32s	remaining: 335ms
# 1748:	learn: 0.0483985	total: 2.33s	remaining: 334ms
# 1749:	learn: 0.0483722	total: 2.33s	remaining: 333ms
# 1750:	learn: 0.0483345	total: 2.33s	remaining: 332ms
# 1751:	learn: 0.0483083	total: 2.33s	remaining: 330ms
# 1752:	learn: 0.0482653	total: 2.33s	remaining: 329ms
# 1753:	learn: 0.0482365	total: 2.34s	remaining: 328ms
# 1754:	learn: 0.0482061	total: 2.34s	remaining: 326ms
# 1755:	learn: 0.0481835	total: 2.34s	remaining: 325ms
# 1756:	learn: 0.0481477	total: 2.34s	remaining: 324ms
# 1757:	learn: 0.0481177	total: 2.34s	remaining: 322ms
# 1758:	learn: 0.0480876	total: 2.34s	remaining: 321ms
# 1759:	learn: 0.0480544	total: 2.34s	remaining: 319ms
# 1760:	learn: 0.0480325	total: 2.34s	remaining: 318ms
# 1761:	learn: 0.0480006	total: 2.35s	remaining: 317ms
# 1762:	learn: 0.0479616	total: 2.35s	remaining: 315ms
# 1763:	learn: 0.0479321	total: 2.35s	remaining: 314ms
# 1764:	learn: 0.0479056	total: 2.35s	remaining: 313ms
# 1765:	learn: 0.0478726	total: 2.35s	remaining: 311ms
# 1766:	learn: 0.0478499	total: 2.35s	remaining: 310ms
# 1767:	learn: 0.0478083	total: 2.35s	remaining: 309ms
# 1768:	learn: 0.0477753	total: 2.35s	remaining: 307ms
# 1769:	learn: 0.0477434	total: 2.35s	remaining: 306ms
# 1770:	learn: 0.0477221	total: 2.36s	remaining: 305ms
# 1771:	learn: 0.0476922	total: 2.36s	remaining: 303ms
# 1772:	learn: 0.0476635	total: 2.36s	remaining: 302ms
# 1773:	learn: 0.0476334	total: 2.36s	remaining: 301ms
# 1774:	learn: 0.0475994	total: 2.36s	remaining: 299ms
# 1775:	learn: 0.0475699	total: 2.36s	remaining: 298ms
# 1776:	learn: 0.0475551	total: 2.36s	remaining: 297ms
# 1777:	learn: 0.0475291	total: 2.37s	remaining: 295ms
# 1778:	learn: 0.0474960	total: 2.37s	remaining: 294ms
# 1779:	learn: 0.0474654	total: 2.37s	remaining: 293ms
# 1780:	learn: 0.0474217	total: 2.37s	remaining: 291ms
# 1781:	learn: 0.0473952	total: 2.37s	remaining: 290ms
# 1782:	learn: 0.0473769	total: 2.37s	remaining: 289ms
# 1783:	learn: 0.0473467	total: 2.37s	remaining: 287ms
# 1784:	learn: 0.0473179	total: 2.37s	remaining: 286ms
# 1785:	learn: 0.0472887	total: 2.38s	remaining: 285ms
# 1786:	learn: 0.0472551	total: 2.38s	remaining: 283ms
# 1787:	learn: 0.0472298	total: 2.38s	remaining: 282ms
# 1788:	learn: 0.0471881	total: 2.38s	remaining: 281ms
# 1789:	learn: 0.0471727	total: 2.38s	remaining: 279ms
# 1790:	learn: 0.0471409	total: 2.38s	remaining: 278ms
# 1791:	learn: 0.0471029	total: 2.38s	remaining: 277ms
# 1792:	learn: 0.0470720	total: 2.38s	remaining: 275ms
# 1793:	learn: 0.0470412	total: 2.38s	remaining: 274ms
# 1794:	learn: 0.0470002	total: 2.39s	remaining: 273ms
# 1795:	learn: 0.0469746	total: 2.39s	remaining: 271ms
# 1796:	learn: 0.0469545	total: 2.39s	remaining: 270ms
# 1797:	learn: 0.0469192	total: 2.39s	remaining: 269ms
# 1798:	learn: 0.0468834	total: 2.4s	remaining: 268ms
# 1799:	learn: 0.0468648	total: 2.4s	remaining: 266ms
# 1800:	learn: 0.0468328	total: 2.4s	remaining: 265ms
# 1801:	learn: 0.0468062	total: 2.4s	remaining: 264ms
# 1802:	learn: 0.0467719	total: 2.4s	remaining: 262ms
# 1803:	learn: 0.0467458	total: 2.4s	remaining: 261ms
# 1804:	learn: 0.0467190	total: 2.4s	remaining: 260ms
# 1805:	learn: 0.0466854	total: 2.4s	remaining: 258ms
# 1806:	learn: 0.0466549	total: 2.41s	remaining: 257ms
# 1807:	learn: 0.0466252	total: 2.41s	remaining: 256ms
# 1808:	learn: 0.0466014	total: 2.41s	remaining: 254ms
# 1809:	learn: 0.0465715	total: 2.41s	remaining: 253ms
# 1810:	learn: 0.0465371	total: 2.41s	remaining: 252ms
# 1811:	learn: 0.0465070	total: 2.41s	remaining: 250ms
# 1812:	learn: 0.0464753	total: 2.41s	remaining: 249ms
# 1813:	learn: 0.0464383	total: 2.42s	remaining: 248ms
# 1814:	learn: 0.0464084	total: 2.42s	remaining: 246ms
# 1815:	learn: 0.0463829	total: 2.42s	remaining: 245ms
# 1816:	learn: 0.0463600	total: 2.42s	remaining: 244ms
# 1817:	learn: 0.0463315	total: 2.42s	remaining: 242ms
# 1818:	learn: 0.0463052	total: 2.42s	remaining: 241ms
# 1819:	learn: 0.0462759	total: 2.42s	remaining: 240ms
# 1820:	learn: 0.0462397	total: 2.42s	remaining: 238ms
# 1821:	learn: 0.0462056	total: 2.42s	remaining: 237ms
# 1822:	learn: 0.0461807	total: 2.43s	remaining: 236ms
# 1823:	learn: 0.0461556	total: 2.43s	remaining: 234ms
# 1824:	learn: 0.0461252	total: 2.43s	remaining: 233ms
# 1825:	learn: 0.0461037	total: 2.43s	remaining: 232ms
# 1826:	learn: 0.0460756	total: 2.43s	remaining: 230ms
# 1827:	learn: 0.0460511	total: 2.43s	remaining: 229ms
# 1828:	learn: 0.0460229	total: 2.43s	remaining: 228ms
# 1829:	learn: 0.0459968	total: 2.44s	remaining: 226ms
# 1830:	learn: 0.0459677	total: 2.44s	remaining: 225ms
# 1831:	learn: 0.0459419	total: 2.44s	remaining: 224ms
# 1832:	learn: 0.0459120	total: 2.44s	remaining: 222ms
# 1833:	learn: 0.0458858	total: 2.44s	remaining: 221ms
# 1834:	learn: 0.0458495	total: 2.44s	remaining: 220ms
# 1835:	learn: 0.0458254	total: 2.44s	remaining: 218ms
# 1836:	learn: 0.0457982	total: 2.44s	remaining: 217ms
# 1837:	learn: 0.0457748	total: 2.44s	remaining: 216ms
# 1838:	learn: 0.0457460	total: 2.45s	remaining: 214ms
# 1839:	learn: 0.0457128	total: 2.45s	remaining: 213ms
# 1840:	learn: 0.0456876	total: 2.45s	remaining: 212ms
# 1841:	learn: 0.0456505	total: 2.45s	remaining: 210ms
# 1842:	learn: 0.0456253	total: 2.45s	remaining: 209ms
# 1843:	learn: 0.0455879	total: 2.45s	remaining: 208ms
# 1844:	learn: 0.0455562	total: 2.45s	remaining: 206ms
# 1845:	learn: 0.0455221	total: 2.46s	remaining: 205ms
# 1846:	learn: 0.0454985	total: 2.46s	remaining: 203ms
# 1847:	learn: 0.0454523	total: 2.46s	remaining: 202ms
# 1848:	learn: 0.0454187	total: 2.46s	remaining: 201ms
# 1849:	learn: 0.0453821	total: 2.46s	remaining: 199ms
# 1850:	learn: 0.0453533	total: 2.46s	remaining: 198ms
# 1851:	learn: 0.0453252	total: 2.46s	remaining: 197ms
# 1852:	learn: 0.0452987	total: 2.46s	remaining: 195ms
# 1853:	learn: 0.0452758	total: 2.46s	remaining: 194ms
# 1854:	learn: 0.0452554	total: 2.46s	remaining: 193ms
# 1855:	learn: 0.0452190	total: 2.47s	remaining: 191ms
# 1856:	learn: 0.0451894	total: 2.47s	remaining: 190ms
# 1857:	learn: 0.0451615	total: 2.47s	remaining: 189ms
# 1858:	learn: 0.0451395	total: 2.47s	remaining: 187ms
# 1859:	learn: 0.0450941	total: 2.47s	remaining: 186ms
# 1860:	learn: 0.0450626	total: 2.47s	remaining: 185ms
# 1861:	learn: 0.0450347	total: 2.47s	remaining: 183ms
# 1862:	learn: 0.0450056	total: 2.48s	remaining: 182ms
# 1863:	learn: 0.0449690	total: 2.48s	remaining: 181ms
# 1864:	learn: 0.0449294	total: 2.48s	remaining: 179ms
# 1865:	learn: 0.0448981	total: 2.48s	remaining: 178ms
# 1866:	learn: 0.0448849	total: 2.48s	remaining: 177ms
# 1867:	learn: 0.0448679	total: 2.48s	remaining: 175ms
# 1868:	learn: 0.0448406	total: 2.48s	remaining: 174ms
# 1869:	learn: 0.0448101	total: 2.48s	remaining: 173ms
# 1870:	learn: 0.0447805	total: 2.48s	remaining: 171ms
# 1871:	learn: 0.0447524	total: 2.49s	remaining: 170ms
# 1872:	learn: 0.0447323	total: 2.49s	remaining: 169ms
# 1873:	learn: 0.0447152	total: 2.49s	remaining: 167ms
# 1874:	learn: 0.0446969	total: 2.49s	remaining: 166ms
# 1875:	learn: 0.0446669	total: 2.49s	remaining: 165ms
# 1876:	learn: 0.0446328	total: 2.49s	remaining: 163ms
# 1877:	learn: 0.0445953	total: 2.49s	remaining: 162ms
# 1878:	learn: 0.0445722	total: 2.5s	remaining: 161ms
# 1879:	learn: 0.0445395	total: 2.5s	remaining: 159ms
# 1880:	learn: 0.0445156	total: 2.5s	remaining: 158ms
# 1881:	learn: 0.0444843	total: 2.5s	remaining: 157ms
# 1882:	learn: 0.0444608	total: 2.5s	remaining: 155ms
# 1883:	learn: 0.0444346	total: 2.5s	remaining: 154ms
# 1884:	learn: 0.0444094	total: 2.5s	remaining: 153ms
# 1885:	learn: 0.0443782	total: 2.5s	remaining: 151ms
# 1886:	learn: 0.0443560	total: 2.51s	remaining: 150ms
# 1887:	learn: 0.0443255	total: 2.51s	remaining: 149ms
# 1888:	learn: 0.0442969	total: 2.51s	remaining: 147ms
# 1889:	learn: 0.0442595	total: 2.51s	remaining: 146ms
# 1890:	learn: 0.0442369	total: 2.51s	remaining: 145ms
# 1891:	learn: 0.0442131	total: 2.51s	remaining: 143ms
# 1892:	learn: 0.0441768	total: 2.51s	remaining: 142ms
# 1893:	learn: 0.0441508	total: 2.51s	remaining: 141ms
# 1894:	learn: 0.0441307	total: 2.52s	remaining: 139ms
# 1895:	learn: 0.0440976	total: 2.52s	remaining: 138ms
# 1896:	learn: 0.0440798	total: 2.52s	remaining: 137ms
# 1897:	learn: 0.0440527	total: 2.52s	remaining: 135ms
# 1898:	learn: 0.0440215	total: 2.52s	remaining: 134ms
# 1899:	learn: 0.0439938	total: 2.52s	remaining: 133ms
# 1900:	learn: 0.0439678	total: 2.52s	remaining: 131ms
# 1901:	learn: 0.0439374	total: 2.52s	remaining: 130ms
# 1902:	learn: 0.0439096	total: 2.53s	remaining: 129ms
# 1903:	learn: 0.0438831	total: 2.53s	remaining: 127ms
# 1904:	learn: 0.0438488	total: 2.53s	remaining: 126ms
# 1905:	learn: 0.0438234	total: 2.53s	remaining: 125ms
# 1906:	learn: 0.0438018	total: 2.53s	remaining: 123ms
# 1907:	learn: 0.0437841	total: 2.53s	remaining: 122ms
# 1908:	learn: 0.0437658	total: 2.53s	remaining: 121ms
# 1909:	learn: 0.0437374	total: 2.54s	remaining: 119ms
# 1910:	learn: 0.0437113	total: 2.54s	remaining: 118ms
# 1911:	learn: 0.0436859	total: 2.54s	remaining: 117ms
# 1912:	learn: 0.0436597	total: 2.54s	remaining: 115ms
# 1913:	learn: 0.0436294	total: 2.54s	remaining: 114ms
# 1914:	learn: 0.0435965	total: 2.54s	remaining: 113ms
# 1915:	learn: 0.0435699	total: 2.54s	remaining: 111ms
# 1916:	learn: 0.0435382	total: 2.54s	remaining: 110ms
# 1917:	learn: 0.0435087	total: 2.54s	remaining: 109ms
# 1918:	learn: 0.0434831	total: 2.55s	remaining: 107ms
# 1919:	learn: 0.0434591	total: 2.55s	remaining: 106ms
# 1920:	learn: 0.0434248	total: 2.55s	remaining: 105ms
# 1921:	learn: 0.0433864	total: 2.55s	remaining: 104ms
# 1922:	learn: 0.0433547	total: 2.55s	remaining: 102ms
# 1923:	learn: 0.0433196	total: 2.55s	remaining: 101ms
# 1924:	learn: 0.0433037	total: 2.55s	remaining: 99.5ms
# 1925:	learn: 0.0432651	total: 2.56s	remaining: 98.2ms
# 1926:	learn: 0.0432440	total: 2.56s	remaining: 96.9ms
# 1927:	learn: 0.0432330	total: 2.56s	remaining: 95.5ms
# 1928:	learn: 0.0432061	total: 2.56s	remaining: 94.2ms
# 1929:	learn: 0.0431888	total: 2.56s	remaining: 92.9ms
# 1930:	learn: 0.0431535	total: 2.56s	remaining: 91.5ms
# 1931:	learn: 0.0431255	total: 2.56s	remaining: 90.2ms
# 1932:	learn: 0.0430908	total: 2.56s	remaining: 88.9ms
# 1933:	learn: 0.0430522	total: 2.56s	remaining: 87.6ms
# 1934:	learn: 0.0430339	total: 2.57s	remaining: 86.2ms
# 1935:	learn: 0.0430110	total: 2.57s	remaining: 84.9ms
# 1936:	learn: 0.0429808	total: 2.57s	remaining: 83.6ms
# 1937:	learn: 0.0429479	total: 2.57s	remaining: 82.3ms
# 1938:	learn: 0.0429228	total: 2.57s	remaining: 81ms
# 1939:	learn: 0.0428999	total: 2.58s	remaining: 79.8ms
# 1940:	learn: 0.0428730	total: 2.58s	remaining: 78.5ms
# 1941:	learn: 0.0428352	total: 2.58s	remaining: 77.1ms
# 1942:	learn: 0.0427917	total: 2.58s	remaining: 75.8ms
# 1943:	learn: 0.0427629	total: 2.59s	remaining: 74.5ms
# 1944:	learn: 0.0427345	total: 2.59s	remaining: 73.2ms
# 1945:	learn: 0.0427113	total: 2.59s	remaining: 71.8ms
# 1946:	learn: 0.0426860	total: 2.59s	remaining: 70.5ms
# 1947:	learn: 0.0426577	total: 2.59s	remaining: 69.1ms
# 1948:	learn: 0.0426400	total: 2.59s	remaining: 67.8ms
# 1949:	learn: 0.0426193	total: 2.59s	remaining: 66.5ms
# 1950:	learn: 0.0425879	total: 2.59s	remaining: 65.1ms
# 1951:	learn: 0.0425616	total: 2.59s	remaining: 63.8ms
# 1952:	learn: 0.0425382	total: 2.6s	remaining: 62.5ms
# 1953:	learn: 0.0425138	total: 2.6s	remaining: 61.1ms
# 1954:	learn: 0.0424816	total: 2.6s	remaining: 59.8ms
# 1955:	learn: 0.0424583	total: 2.6s	remaining: 58.5ms
# 1956:	learn: 0.0424291	total: 2.6s	remaining: 57.1ms
# 1957:	learn: 0.0424044	total: 2.6s	remaining: 55.8ms
# 1958:	learn: 0.0423766	total: 2.6s	remaining: 54.4ms
# 1959:	learn: 0.0423528	total: 2.6s	remaining: 53.1ms
# 1960:	learn: 0.0423224	total: 2.6s	remaining: 51.8ms
# 1961:	learn: 0.0422987	total: 2.6s	remaining: 50.5ms
# 1962:	learn: 0.0422711	total: 2.61s	remaining: 49.1ms
# 1963:	learn: 0.0422418	total: 2.61s	remaining: 47.8ms
# 1964:	learn: 0.0422108	total: 2.61s	remaining: 46.5ms
# 1965:	learn: 0.0421882	total: 2.61s	remaining: 45.1ms
# 1966:	learn: 0.0421694	total: 2.61s	remaining: 43.8ms
# 1967:	learn: 0.0421466	total: 2.61s	remaining: 42.5ms
# 1968:	learn: 0.0421191	total: 2.61s	remaining: 41.2ms
# 1969:	learn: 0.0420996	total: 2.62s	remaining: 39.8ms
# 1970:	learn: 0.0420717	total: 2.62s	remaining: 38.5ms
# 1971:	learn: 0.0420450	total: 2.62s	remaining: 37.2ms
# 1972:	learn: 0.0420202	total: 2.62s	remaining: 35.8ms
# 1973:	learn: 0.0419958	total: 2.62s	remaining: 34.5ms
# 1974:	learn: 0.0419758	total: 2.62s	remaining: 33.2ms
# 1975:	learn: 0.0419538	total: 2.62s	remaining: 31.9ms
# 1976:	learn: 0.0419261	total: 2.62s	remaining: 30.5ms
# 1977:	learn: 0.0418981	total: 2.63s	remaining: 29.2ms
# 1978:	learn: 0.0418726	total: 2.63s	remaining: 27.9ms
# 1979:	learn: 0.0418469	total: 2.63s	remaining: 26.5ms
# 1980:	learn: 0.0418218	total: 2.63s	remaining: 25.2ms
# 1981:	learn: 0.0418039	total: 2.63s	remaining: 23.9ms
# 1982:	learn: 0.0417837	total: 2.63s	remaining: 22.6ms
# 1983:	learn: 0.0417599	total: 2.63s	remaining: 21.2ms
# 1984:	learn: 0.0417363	total: 2.63s	remaining: 19.9ms
# 1985:	learn: 0.0417139	total: 2.63s	remaining: 18.6ms
# 1986:	learn: 0.0416915	total: 2.64s	remaining: 17.3ms
# 1987:	learn: 0.0416691	total: 2.64s	remaining: 15.9ms
# 1988:	learn: 0.0416373	total: 2.64s	remaining: 14.6ms
# 1989:	learn: 0.0416138	total: 2.64s	remaining: 13.3ms
# 1990:	learn: 0.0415903	total: 2.64s	remaining: 11.9ms
# 1991:	learn: 0.0415655	total: 2.64s	remaining: 10.6ms
# 1992:	learn: 0.0415419	total: 2.64s	remaining: 9.29ms
# 1993:	learn: 0.0415127	total: 2.65s	remaining: 7.96ms
# 1994:	learn: 0.0414807	total: 2.65s	remaining: 6.63ms
# 1995:	learn: 0.0414547	total: 2.65s	remaining: 5.31ms
# 1996:	learn: 0.0414301	total: 2.65s	remaining: 3.98ms
# 1997:	learn: 0.0414107	total: 2.65s	remaining: 2.65ms
# 1998:	learn: 0.0413843	total: 2.65s	remaining: 1.33ms
# 1999:	learn: 0.0413590	total: 2.65s	remaining: 0us
# Best Accuracy: 60.54 %
# Best Parameters: {'n_estimators': 2000}

# %% [markdown]
# ##ADABoost

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier()

parameters = [{'estimator': [RandomForestClassifier(), GradientBoostingClassifier()], 'n_estimators': [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]}]
grid_search = GridSearchCV(estimator = ada,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)
grid_search.fit(X_train, y_train)
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_
print("Best Accuracy: {:.2f} %".format(best_accuracy*100))
print("Best Parameters:", best_parameters)
# Out:
# Best Accuracy: 61.96 %
# Best Parameters: {'estimator': RandomForestClassifier(), 'n_estimators': 8000}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
ada = AdaBoostClassifier()

parameters = [{'estimator': [AdaBoostClassifier(estimator=RandomForestClassifier(n_estimators=5000), n_estimators=10000, learning_rate=0.01)], 'n_estimators': [10, 50, 100, 500, 1000, 2000, 5000], 'learning_rate' : [0.1, 0.01, 0.001]}]
grid_search = GridSearchCV(estimator = ada,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)
grid_search.fit(X_train, y_train)
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_
print("Best Accuracy: {:.2f} %".format(best_accuracy*100))
print("Best Parameters:", best_parameters)
# Out:
# Best Accuracy: 60.54 %
# Best Parameters: {'estimator': AdaBoostClassifier(estimator=RandomForestClassifier(n_estimators=5000),
#                    learning_rate=0.01, n_estimators=10000), 'learning_rate': 0.1, 'n_estimators': 10}

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score


ada2 = AdaBoostClassifier(estimator=GradientBoostingClassifier(n_estimators=5000), n_estimators=10000, learning_rate=0.01, random_state=0)
accuracies = cross_val_score(estimator = ada2, X = X_train, y = y_train, cv = 6)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 59.19 %
# Standard Deviation: 8.39 %

# %%
# accuracies

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

ada_final = AdaBoostClassifier(estimator=GradientBoostingClassifier(n_estimators=5000), n_estimators=4000, learning_rate=0.01, random_state=0)
ada_final.fit(X_train, y_train)
y_pred_ada = ada_final.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred_ada)

print(cm)
print("\n")
print(accuracy_score(y_test, y_pred_ada)*100)
print(f'Precision : {precision_score(y_test, y_pred_ada, average="macro")}')
print(f'Recall : {recall_score(y_test, y_pred_ada, average="macro")*100}')
print(f'F1 Score : {f1_score(y_test, y_pred_ada, average="macro")*100}')
# Out:
# [[2 0 0 0 1 0]
#  [0 4 0 0 0 0]
#  [1 0 2 0 1 1]
#  [0 0 0 1 0 1]
#  [0 0 0 0 4 0]
#  [0 0 0 0 1 1]]
#
#
# 70.0
# Precision : 0.7619047619047619
# Recall : 67.77777777777777
# F1 Score : 67.2005772005772

# %% [markdown]
# ##PICKLE

# %%
# import pickle

# with open('STAI_model_Final_wBA.pkl', 'wb') as f:
#     pickle.dump(ada_final, f)

# %%
# import pickle

# with open('STAI_model_Final_wBA.pkl', 'rb') as f:
#     model = pickle.load(f)

# y_pred_f = model.predict([[1, 35, 0, 1, 1, 0, 1, 26.7]])
# print(y_pred_f)

# %%
# print(model)
